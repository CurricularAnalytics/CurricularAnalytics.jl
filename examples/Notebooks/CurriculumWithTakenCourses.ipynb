# %%
if split(pwd(),Base.Filesystem.path_separator)[end] != "CurricularAnalytics.jl"
    cd("../..")
end
println("Current directory: " * split(pwd(),Base.Filesystem.path_separator)[end])
using Pkg
pkg"activate ."
using CurricularAnalytics
include("src/Optimization.jl")
# Out:
# Current directory: CurricularAnalytics.jl
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/41794c50334d4e214c4ed8746cf62efbfa8785f6-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/41794c50334d4e214c4ed8746cf62efbfa8785f6-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")
# optimize_plan (generic function with 2 methods)

# %%
optimize_plan("examples/Notebooks/Opt_Configurations-2.csv", "examples/UKY_EE_unfixed.csv",
    "examples/Notebooks/CourseCombinationsWithCond.csv")
# Out:
# End of file
# Number of courses in curriculum: 43
# Total credit hours: 131
# Academic license - for non-commercial use only
# Optimize a model with 88 rows, 352 columns and 1496 nonzeros
# Variable types: 8 continuous, 344 integer (344 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 0 rows and 73 columns
# Presolve time: 0.01s
# Presolved: 88 rows, 279 columns, 1056 nonzeros
# Variable types: 0 continuous, 279 integer (279 binary)
# Found heuristic solution: objective 42.0000000
#
# Root relaxation: objective 2.100000e+01, 114 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   21.00000    0   31   42.00000   21.00000  50.0%     -    0s
# H    0     0                      26.0000000   21.00000  19.2%     -    0s
# H    0     0                      24.0000000   21.00000  12.5%     -    0s
# H    0     0                      22.0000000   21.00000  4.55%     -    0s
# H    0     0                      21.0000000   21.00000  0.00%     -    0s
#      0     0   21.00000    0   44   21.00000   21.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 6
#   Clique: 28
#   MIR: 3
#   StrongCG: 2
#   GUB cover: 10
#
# Explored 1 nodes (204 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 21 22 24 ... 42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.100000000000e+01, best bound 2.100000000000e+01, gap 0.0000%
# 21.0
# WebIO.Scope("scope-f0f75179-49b3-4487-ae0e-9050a5dd3344", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"curriculum\":{\"name\":\"University of Kentucky EE Program\",\"dp_name\":\"University of Kentucky EE Program 4-year Plan\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"EE Technical Elective 3\",\"id\":3472050261,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"Engineering/Science Elective 1\",\"id\":1824271747,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"EE Technical Elective 2\",\"id\":2900608954,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"UK Core - Humanities\",\"id\":699408466,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"Technical Elective 2\",\"id\":3697264218,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"EE Technical Elective 4\",\"id\":3141179749,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"UK Core - Statistical Inferential Reasoning\",\"id\":599971617,\"credits\":3,\"nameCanonical\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\"EGR 102\",\"metrics\":{\"centrality\":0,\"complexity\":6.0,\"blocking factor\":3,\"delay factor\":3.0},\"nameSub\":\"Fundamentals of Engineering Computing\",\"id\":502542156,\"credits\":2,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"Technical Elective 1\",\"id\":3654615878,\"credits\":3,\"nameCanonical\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\"CHE 105\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"nameSub\":\"General College Chemistry I\",\"id\":738464693,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":2865398329,\"target_id\":746915474,\"type\":\"coreq\"}],\"name\":\"PHY 241\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":0,\"delay factor\":3.0},\"nameSub\":\"General University Physics Lab\",\"id\":746915474,\"credits\":1,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3389674827,\"target_id\":2865398329,\"type\":\"coreq\"}],\"name\":\"PHY 231\",\"metrics\":{\"centrality\":62,\"complexity\":16.0,\"blocking factor\":10,\"delay factor\":6.0},\"nameSub\":\"General University Physics\",\"id\":2865398329,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":502542156,\"target_id\":1123828828,\"type\":\"prereq\"},{\"source_id\":3389674827,\"target_id\":1123828828,\"type\":\"coreq\"},{\"source_id\":2865398329,\"target_id\":1123828828,\"type\":\"coreq\"},{\"source_id\":738464693,\"target_id\":1123828828,\"type\":\"coreq\"}],\"name\":\"EGR 103\",\"metrics\":{\"centrality\":0,\"complexity\":3.0 ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"curriculum"=>Dict{String,Any}("name"=>"University of Kentucky EE Program","dp_name"=>"University of Kentucky EE Program 4-year Plan","curriculum_terms"=>Dict{String,Any}[Dict("name"=>"Term 1","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"EE Technical Elective 3","id"=>3472050261,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"Engineering/Science Elective 1","id"=>1824271747,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"EE Technical Elective 2","id"=>2900608954,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"UK Core - Humanities","id"=>699408466,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"Technical Elective 2","id"=>3697264218,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"EE Technical Elective 4","id"=>3141179749,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"UK Core - Statistical Inferential Reasoning","id"=>599971617,"credits"=>3,"nameCanonical"=>"")],"id"=>1), Dict("name"=>"Term 2","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"EGR 102","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>6.0,"blocking factor"=>3,"delay factor"=>3.0),"nameSub"=>"Fundamentals of Engineering Computing","id"=>502542156,"credits"=>2,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"Technical Elective 1","id"=>3654615878,"credits"=>3,"nameCanonical"=>"")],"id"=>2), Dict("name"=>"Term 3","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"CHE 105","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"nameSub"=>"General College Chemistry I","id"=>738464693,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>2865398329,"target_id"=>746915474,"type"=>"coreq")],"name"=>"PHY 241","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>0,"delay factor"=>3.0),"nameSub"=>"General University Physics Lab","id"=>746915474,"credits"=>1,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>3389674827,"target_id"=>2865398329,"type"=>"coreq")],"name"=>"PHY 231","metrics"=>Dict{String,Any}("centrality"=>62,"complexity"=>16.0,"blocking factor"=>10,"delay factor"=>6.0),"nameSub"=>"General University Physics","id"=>2865398329,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>502542156,"target_id"=>1123828828,"type"=>"prereq"), Dict("source_id"=>3389674827,"target_id"=>1123828828,"type"=>"coreq"), Dict("source_id"=>2865398329,"target_id"=>1123828828,"type"=>"coreq"), Dict("source_id"=>738464693,"target_id"= ...

# %%
optimize_plan("examples/Notebooks/Opt_Configurations-3.csv", "examples/UKY_EE_unfixed.csv",
    "examples/Notebooks/CourseCombinationsWithCond.csv")
# Out:
# Number of courses in curriculum: 43
# Total credit hours: 131
# Dict{Any,Any}(4=>19,2=>19,3=>19,5=>19,6=>10,1=>15)
# 15
# 6
# 26
# Academic license - for non-commercial use only
# Optimize a model with 107 rows, 264 columns and 2289 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 60 rows and 111 columns
# Presolve time: 0.01s
# Presolved: 47 rows, 153 columns, 839 nonzeros
# Variable types: 0 continuous, 153 integer (147 binary)
#
# Root relaxation: infeasible, 38 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 0 nodes (38 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# not optimal
# ┌ Warning: Not solved to optimality, status: Infeasible
# └ @ JuMP /Users/heileman/.julia/packages/JuMP/PbnIJ/src/solvers.jl:212
# ┌ Warning: Infeasibility ray (Farkas proof) not available
# └ @ JuMP /Users/heileman/.julia/packages/JuMP/PbnIJ/src/solvers.jl:223

# %%
optimize_plan("examples/Notebooks/Opt_Configurations-4.csv", "examples/UKY_EE_unfixed.csv",
    "examples/Notebooks/CourseCombinationsWithCond.csv")

# %%
optimize_plan("examples/Notebooks/Opt_Configurations.csv", "examples/UKY_EE_partial.csv",
    "examples/Notebooks/CourseCombinationsWithCond.csv")
# Out:
# Got there
# Number of courses in curriculum: 32
# Total credit hours: 131
# 15
# Academic license - for non-commercial use only
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Variable types: 0 continuous, 159 integer (150 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 1.250000e+01, 71 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.50000    0   11   14.00000   12.50000  10.7%     -    0s
#      0     0   13.00000    0   10   14.00000   13.00000  7.14%     -    0s
# H    0     0                      13.0000000   13.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Clique: 6
#   MIR: 5
#
# Explored 1 nodes (168 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 13 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [4e+00, 4e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 21.4792
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 0.000000e+00, 81 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   30   21.47918    0.00000   100%     -    0s
# H    0     0                      15.9568971    0.00000   100%     -    0s
# H    0     0                      11.9761317    0.00000   100%     -    0s
#      0     0    3.01778    0   28   11.97613    3.01778  74.8%     -    0s
#      0     0    3.01778    0   30   11.97613    3.01778  74.8%     -    0s
#      0     0    4.08237    0   17   11.97613    4.08237  65.9%     -    0s
# H    0     0                      10.0203998    4.08237  59.3%     -    0s
#      0     0    4.08237    0   17   10.02040    4.08237  59.3%     -    0s
#      0     0    4.08237    0   13   10.02040    4.08237  59.3%     -    0s
# H    0     0                       8.0071838    4.08237  49.0%     -    0s
#      0     0    4.08237    0   17    8.00718    4.08237  49.0%     -    0s
# H    0     0                       6.0859975    4.08237  32.9%     -    0s
#      0     0    4.34961    0   27    6.08600    4.34961  28.5%     -    0s
#      0     0    4.34961    0   27    6.08600    4.34961  28.5%     -    0s
#      0     0    4.72225    0   24    6.08600    4.72225  22.4%     -    0s
#      0     0    5.05621    0   11    6.08600    5.05621  16.9%     -    0s
#      0     0    5.05621    0   11    6.08600    5.05621  16.9%     -    0s
# H    0     0                       6.0300447    5.05621  16.1%     -    0s
#      0     0    5.05621    0   11    6.03004    5.05621  16.1%     -    0s
#
# Cutting planes:
#   Cover: 5
#   Clique: 3
#   MIR: 5
#   Zero half: 4
#
# Explored 1 nodes (576 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 6.03004 6.086 8.00718 ... 21.4792
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.030044722634e+00, best bound 6.030044722634e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 31
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 151 columns, 480 nonzeros
# Variable types: 0 continuous, 151 integer (150 binary)
#
# Root relaxation: objective 1.730769e+01, 85 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.30769    0   25   31.00000   17.30769  44.2%     -    0s
#      0     0   18.00000    0   15   31.00000   18.00000  41.9%     -    0s
# H    0     0                      25.0000000   18.00000  28.0%     -    0s
#      0     0   18.10714    0   41   25.00000   18.10714  27.6%     -    0s
#      0     0   18.13333    0   41   25.00000   18.13333  27.5%     -    0s
#      0     0   18.52456    0   49   25.00000   18.52456  25.9%     -    0s
#      0     0   18.63415    0   45   25.00000   18.63415  25.5%     -    0s
#      0     0   18.65094    0   46   25.00000   18.65094  25.4%     -    0s
#      0     0   18.65094    0   46   25.00000   18.65094  25.4%     -    0s
# H    0     0                      22.0000000   18.65094  15.2%     -    0s
#      0     0   18.71353    0   46   22.00000   18.71353  14.9%     -    0s
# H    0     0                      21.0000000   18.71353  10.9%     -    0s
# H    0     0                      20.0000000   18.71353  6.43%     -    0s
#      0     0   19.00000    0   48   20.00000   19.00000  5.00%     -    0s
#      0     0   19.00000    0   38   20.00000   19.00000  5.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 7
#   Clique: 5
#   MIR: 7
#   GUB cover: 1
#   Zero half: 1
#   Mod-K: 3
#
# Explored 1 nodes (297 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 20 21 22 ... 31
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [6e-02, 2e+00]
#   QObjective range [2e-02, 2e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.41439
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 1.174236e+00, 135 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.17424    0   38    1.41439    1.17424  17.0%     -    0s
#      0     0    1.28072    0   60    1.41439    1.28072  9.45%     -    0s
#      0     0    1.28072    0   59    1.41439    1.28072  9.45%     -    0s
#      0     2    1.28072    0   58    1.41439    1.28072  9.45%     -    0s
#
# Cutting planes:
#   Cover: 4
#   Clique: 34
#   MIR: 5
#   Zero half: 13
#
# Explored 40 nodes (830 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.41439
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.414392581508e+00, best bound 1.414392581508e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [6e-02, 1e+00]
#   QObjective range [4e-02, 5e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.40021
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 1.027778e+00, 106 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.02778    0   32    1.40021    1.02778  26.6%     -    0s
# H    0     0                       1.3896802    1.02778  26.0%     -    0s
#      0     0    1.22726    0   43    1.38968    1.22726  11.7%     -    0s
#      0     0    1.22726    0   41    1.38968    1.22726  11.7%     -    0s
#      0     2    1.22726    0   38    1.38968    1.22726  11.7%     -    0s
#
# Cutting planes:
#   Cover: 9
#   Clique: 39
#   MIR: 11
#   GUB cover: 1
#   Zero half: 5
#
# Explored 41 nodes (916 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.38968 1.40021
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.389680199052e+00, best bound 1.389680199052e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [5e-02, 1e+00]
#   QObjective range [6e-02, 7e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.33452
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 8.809524e-01, 110 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.88095    0   32    1.33452    0.88095  34.0%     -    0s
#      0     0    1.14447    0   41    1.33452    1.14447  14.2%     -    0s
#      0     0    1.18830    0   60    1.33452    1.18830  11.0%     -    0s
#      0     0    1.18830    0   57    1.33452    1.18830  11.0%     -    0s
#      0     2    1.18830    0   57    1.33452    1.18830  11.0%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 5
#   Clique: 30
#   MIR: 10
#   Zero half: 5
#
# Explored 34 nodes (842 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.33452
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.334520298578e+00, best bound 1.334520298578e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-02, 1e+00]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.27936
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 7.341270e-01, 122 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.73413    0   33    1.27936    0.73413  42.6%     -    0s
#      0     0    1.06024    0   43    1.27936    1.06024  17.1%     -    0s
#      0     0    1.06024    0   43    1.27936    1.06024  17.1%     -    0s
#      0     2    1.06024    0   43    1.27936    1.06024  17.1%     -    0s
# *  153     6              16       1.2595469    1.24641  1.04%   9.7    0s
# *  188     0              14       1.2528654    1.25287  0.00%   9.2    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 7
#   Clique: 39
#   MIR: 5
#   GUB cover: 1
#   Zero half: 10
#
# Explored 193 nodes (2049 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1.25287 1.25955 1.27936
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.252865405895e+00, best bound 1.252865405895e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-02, 8e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.1018
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 5.873016e-01, 96 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.58730    0   32    1.10180    0.58730  46.7%     -    0s
#      0     0    0.96113    0   47    1.10180    0.96113  12.8%     -    0s
#      0     0    1.00369    0   44    1.10180    1.00369  8.90%     -    0s
#      0     0    1.00369    0   44    1.10180    1.00369  8.90%     -    0s
#      0     2    1.00369    0   43    1.10180    1.00369  8.90%     -    0s
# *  113     3              16       1.0897623    1.08976  0.00%  10.1    0s
#
# Cutting planes:
#   Cover: 7
#   Clique: 22
#   MIR: 10
#   GUB cover: 1
#   Zero half: 2
#
# Explored 117 nodes (1621 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.08976 1.1018
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.089762325012e+00, best bound 1.089762325012e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [2e-02, 6e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.893429
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 4.404762e-01, 95 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.44048    0   32    0.89343    0.44048  50.7%     -    0s
#      0     0    0.81600    0   55    0.89343    0.81600  8.67%     -    0s
#      0     0    0.85012    0   13    0.89343    0.85012  4.85%     -    0s
#      0     0    0.85012    0   10    0.89343    0.85012  4.85%     -    0s
#      0     0    0.86962    0    4    0.89343    0.86962  2.66%     -    0s
#      0     0 infeasible    0         0.89343    0.89343  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   MIR: 1
#
# Explored 1 nodes (540 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.893429
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.934290757292e-01, best bound 8.934290757292e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [2e-02, 4e-01]
#   QObjective range [1e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.697096
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 2.936508e-01, 81 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.29365    0   30    0.69710    0.29365  57.9%     -    0s
#      0     0    0.62875    0   39    0.69710    0.62875  9.80%     -    0s
#      0     0    0.68122    0    8    0.69710    0.68122  2.28%     -    0s
#      0     0    0.68122    0    8    0.69710    0.68122  2.28%     -    0s
#      0     0 infeasible    0         0.69710    0.69710  0.00%     -    0s
#
# Explored 1 nodes (277 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.697096
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.970958264460e-01, best bound 6.970958264460e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [8e-03, 2e-01]
#   QObjective range [2e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.500763
# MIP start did not produce a new incumbent solution
#
# Presolve removed 31 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 1.468254e-01, 84 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.14683    0   32    0.50076    0.14683  70.7%     -    0s
#      0     0    0.41921    0   18    0.50076    0.41921  16.3%     -    0s
#      0     0    0.46016    0   38    0.50076    0.46016  8.11%     -    0s
#      0     0    0.49283    0    4    0.50076    0.49283  1.58%     -    0s
#      0     0    0.49283    0    9    0.50076    0.49283  1.58%     -    0s
#      0     0    0.49283    0   10    0.50076    0.49283  1.58%     -    0s
#      0     0    0.49283    0    6    0.50076    0.49283  1.58%     -    0s
#      0     0 infeasible    0         0.50076    0.50076  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 6
#   MIR: 1
#
# Explored 1 nodes (591 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.500763
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.007625771627e-01, best bound 5.007625771627e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 2e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.97
# Loaded MIP start with objective 1.86024
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Found heuristic solution: objective 1.8602400
# Variable types: 0 continuous, 159 integer (150 binary)
#
# Root relaxation: objective 1.115839e+00, 132 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.11584    0   33    1.86024    1.11584  40.0%     -    0s
#      0     0    1.15979    0   17    1.86024    1.15979  37.7%     -    0s
# H    0     0                       1.4779326    1.15979  21.5%     -    0s
#      0     0    1.16014    0   16    1.47793    1.16014  21.5%     -    0s
#      0     0    1.19373    0   40    1.47793    1.19373  19.2%     -    0s
#      0     0    1.19433    0   39    1.47793    1.19433  19.2%     -    0s
# H    0     0                       1.3523035    1.19433  11.7%     -    0s
#      0     0    1.19458    0   40    1.35230    1.19458  11.7%     -    0s
# H    0     0                       1.2888115    1.19458  7.31%     -    0s
#      0     0    1.21180    0   58    1.28881    1.21180  5.98%     -    0s
#      0     0    1.22698    0   51    1.28881    1.22698  4.80%     -    0s
#      0     0    1.22698    0   51    1.28881    1.22698  4.80%     -    0s
#      0     0    1.22759    0   26    1.28881    1.22759  4.75%     -    0s
#      0     0    1.22847    0   54    1.28881    1.22847  4.68%     -    0s
#      0     0    1.22910    0   53    1.28881    1.22910  4.63%     -    0s
#      0     0    1.22910    0   56    1.28881    1.22910  4.63%     -    0s
#      0     0    1.22910    0   56    1.28881    1.22910  4.63%     -    0s
#      0     0    1.22910    0   49    1.28881    1.22910  4.63%     -    0s
#      0     0    1.22910    0   12    1.28881    1.22910  4.63%     -    0s
#      0     0    1.22910    0   20    1.28881    1.22910  4.63%     -    0s
#      0     0    1.22910    0   27    1.28881    1.22910  4.63%     -    0s
#      0     0    1.22910    0   35    1.28881    1.22910  4.63%     -    0s
#      0     0    1.23114    0   30    1.28881    1.23114  4.47%     -    0s
#      0     0    1.23554    0   32    1.28881    1.23554  4.13%     -    0s
#      0     0    1.23846    0   32    1.28881    1.23846  3.91%     -    0s
#      0     0    1.23919    0   37    1.28881    1.23919  3.85%     -    0s
#      0     0    1.23964    0   38    1.28881    1.23964  3.82%     -    0s
#      0     0    1.23972    0   39    1.28881    1.23972  3.81%     -    0s
#      0     0    1.24286    0   39    1.28881    1.24286  3.57%     -    0s
#      0     0    1.24331    0   42    1.28881    1.24331  3.53%     -    0s
#      0     0    1.24344    0   42    1.28881    1.24344  3.52%     -    0s
#      0     0    1.24676    0   44    1.28881    1.24676  3.26%     -    0s
#      0     0    1.24692    0   37    1.28881    1.24692  3.25%     -    0s
#      0     0    1.24704    0   45    1.28881    1.24704  3.24%     -    0s
#      0     0     cutoff    0         1.28881    1.28881  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 4
#   Clique: 3
#   MIR: 11
#   StrongCG: 2
#   Mod-K: 5
#
# Explored 1 nodes (702 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.28881 1.3523 1.47793 ... 1.96458
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.288811459543e+00, best bound 1.288811459543e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [2e-02, 2e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.27463
# Loaded MIP start with objective 1.27463
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 1.044715e+00, 148 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.04472    0   40    1.27463    1.04472  18.0%     -    0s
#      0     0    1.14467    0   62    1.27463    1.14467  10.2%     -    0s
#      0     0    1.15013    0   61    1.27463    1.15013  9.77%     -    0s
#      0     0    1.15013    0   61    1.27463    1.15013  9.77%     -    0s
#      0     0    1.15013    0   34    1.27463    1.15013  9.77%     -    0s
#      0     0    1.15013    0   54    1.27463    1.15013  9.77%     -    0s
#      0     0    1.15013    0   54    1.27463    1.15013  9.77%     -    0s
#      0     1    1.15013    0   52    1.27463    1.15013  9.77%     -    0s
#
# Cutting planes:
#   Cover: 7
#   MIR: 2
#   Zero half: 16
#
# Explored 27 nodes (750 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.27463
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.274632612480e+00, best bound 1.274632612480e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [4e-02, 5e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.26045
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 8.978901e-01, 152 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.89789    0   40    1.26045    0.89789  28.8%     -    0s
#      0     0    1.08944    0   53    1.26045    1.08944  13.6%     -    0s
#      0     0    1.11969    0   61    1.26045    1.11969  11.2%     -    0s
#      0     0    1.11969    0   59    1.26045    1.11969  11.2%     -    0s
# H    0     0                       1.2419837    1.11969  9.85%     -    0s
#      0     2    1.11969    0   62    1.24198    1.11969  9.85%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 6
#   Clique: 28
#   MIR: 9
#   GUB cover: 1
#   Zero half: 10
#
# Explored 39 nodes (929 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.24198 1.26045
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.241983722087e+00, best bound 1.241983722087e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [6e-02, 7e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.18682
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 7.510647e-01, 150 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.75106    0   39    1.18682    0.75106  36.7%     -    0s
#      0     0    1.00664    0   51    1.18682    1.00664  15.2%     -    0s
#      0     0    1.00664    0   48    1.18682    1.00664  15.2%     -    0s
#      0     2    1.00664    0   47    1.18682    1.00664  15.2%     -    0s
#
# Cutting planes:
#   Cover: 6
#   Clique: 39
#   MIR: 7
#   GUB cover: 1
#   Zero half: 11
#
# Explored 37 nodes (1035 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.18682
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.186823821613e+00, best bound 1.186823821613e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 8e-01]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.13166
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 6.042393e-01, 160 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.60424    0   41    1.13166    0.60424  46.6%     -    0s
#      0     0    0.91845    0   55    1.13166    0.91845  18.8%     -    0s
#      0     0    0.91845    0   48    1.13166    0.91845  18.8%     -    0s
#      0     2    0.91845    0   48    1.13166    0.91845  18.8%     -    0s
# H   24    15                       1.1066531    0.99926  9.70%  12.8    0s
# H  131    22                       1.0749070    1.04181  3.08%  10.0    0s
# *  178     7              10       1.0654864    1.04452  1.97%   9.7    0s
# *  190     0              11       1.0641314    1.05144  1.19%   9.7    0s
#
# Cutting planes:
#   Cover: 6
#   Clique: 34
#   MIR: 6
#   Zero half: 12
#
# Explored 195 nodes (2356 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.06413 1.06549 1.07491 ... 1.13166
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.064131375697e+00, best bound 1.064131375697e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 6e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.913062
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 4.574139e-01, 120 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.45741    0   40    0.91306    0.45741  49.9%     -    0s
#      0     0    0.79747    0   62    0.91306    0.79747  12.7%     -    0s
#      0     0    0.82291    0   50    0.91306    0.82291  9.87%     -    0s
#      0     0    0.82351    0   47    0.91306    0.82351  9.81%     -    0s
#      0     0    0.82351    0   45    0.91306    0.82351  9.81%     -    0s
#      0     2    0.82351    0   45    0.91306    0.82351  9.81%     -    0s
# H    4     4                       0.9023833    0.84446  6.42%  24.8    0s
# *   78     4               9       0.8785738    0.85341  2.86%   6.4    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 8
#   Clique: 28
#   MIR: 5
#   Zero half: 7
#
# Explored 97 nodes (1195 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.878574 0.902383 0.913062
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.785737845556e-01, best bound 8.785737845556e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 4e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.682241
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 3.105885e-01, 110 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.31059    0   42    0.68224    0.31059  54.5%     -    0s
#      0     0    0.62191    0   47    0.68224    0.62191  8.84%     -    0s
#      0     0    0.66433    0   18    0.68224    0.66433  2.62%     -    0s
#      0     0    0.66433    0   18    0.68224    0.66433  2.62%     -    0s
#      0     0    0.66433    0   14    0.68224    0.66433  2.62%     -    0s
#      0     0    0.68156    0    6    0.68224    0.68156  0.10%     -    0s
#      0     0 infeasible    0         0.68224    0.68224  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 7
#
# Explored 1 nodes (390 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.682241
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.822405352724e-01, best bound 6.822405352724e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 2e-01]
#   QObjective range [1e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.485907
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 1.637631e-01, 131 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.16376    0   42    0.48591    0.16376  66.3%     -    0s
#      0     0    0.41351    0   26    0.48591    0.41351  14.9%     -    0s
#      0     0    0.41351    0   30    0.48591    0.41351  14.9%     -    0s
#      0     0    0.44820    0   45    0.48591    0.44820  7.76%     -    0s
#      0     0    0.47662    0    3    0.48591    0.47662  1.91%     -    0s
#      0     0    0.47662    0    3    0.48591    0.47662  1.91%     -    0s
#      0     0    0.47662    0   13    0.48591    0.47662  1.91%     -    0s
#      0     0    0.48523    0    6    0.48591    0.48523  0.14%     -    0s
#      0     0 infeasible    0         0.48591    0.48591  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 6
#
# Explored 1 nodes (467 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.485907
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.859072859891e-01, best bound 4.859072859891e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e-03]
#   QObjective range [2e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.289574
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 6.371708e-02, 85 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.06372    0   32    0.28957    0.06372  78.0%     -    0s
#      0     0    0.17251    0   36    0.28957    0.17251  40.4%     -    0s
# H    0     0                       0.2851368    0.17251  39.5%     -    0s
#      0     0    0.17319    0   35    0.28514    0.17319  39.3%     -    0s
#      0     0    0.24126    0   22    0.28514    0.24126  15.4%     -    0s
#      0     0    0.25278    0   32    0.28514    0.25278  11.3%     -    0s
#      0     0     cutoff    0         0.28514    0.28514  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 3
#   Implied bound: 1
#   Clique: 4
#   MIR: 7
#   GUB cover: 1
#   Zero half: 11
#
# Explored 1 nodes (266 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.285137 0.289574
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.851367805986e-01, best bound 2.851367805986e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.81301
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Variable types: 0 continuous, 159 integer (150 binary)
#
# Root relaxation: objective 9.954138e-01, 124 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99541    0   33    1.81301    0.99541  45.1%     -    0s
# H    0     0                       1.7628726    0.99541  43.5%     -    0s
# H    0     0                       1.6517615    0.99541  39.7%     -    0s
#      0     0    1.03388    0   18    1.65176    1.03388  37.4%     -    0s
#      0     0    1.03457    0   15    1.65176    1.03457  37.4%     -    0s
# H    0     0                       1.5352304    1.03457  32.6%     -    0s
# H    0     0                       1.3130081    1.03457  21.2%     -    0s
#      0     0    1.05180    0   39    1.31301    1.05180  19.9%     -    0s
#      0     0    1.05735    0   46    1.31301    1.05735  19.5%     -    0s
# H    0     0                       1.2046070    1.05735  12.2%     -    0s
#      0     0    1.07090    0   53    1.20461    1.07090  11.1%     -    0s
#      0     0    1.08074    0   49    1.20461    1.08074  10.3%     -    0s
#      0     0    1.08074    0   53    1.20461    1.08074  10.3%     -    0s
#      0     0    1.08098    0   56    1.20461    1.08098  10.3%     -    0s
#      0     0    1.08157    0   57    1.20461    1.08157  10.2%     -    0s
#      0     0    1.08390    0   57    1.20461    1.08390  10.0%     -    0s
#      0     0    1.08482    0   56    1.20461    1.08482  9.94%     -    0s
#      0     0    1.08487    0   57    1.20461    1.08487  9.94%     -    0s
#      0     0    1.08520    0   54    1.20461    1.08520  9.91%     -    0s
# H    0     0                       1.1490515    1.08520  5.56%     -    0s
#      0     0    1.09475    0   58    1.14905    1.09475  4.73%     -    0s
#      0     0    1.09676    0   47    1.14905    1.09676  4.55%     -    0s
#      0     0    1.09676    0   47    1.14905    1.09676  4.55%     -    0s
#      0     0    1.09676    0   49    1.14905    1.09676  4.55%     -    0s
#      0     0    1.09676    0   50    1.14905    1.09676  4.55%     -    0s
#      0     0    1.09720    0   49    1.14905    1.09720  4.51%     -    0s
#      0     0    1.09720    0   12    1.14905    1.09720  4.51%     -    0s
#      0     2    1.09720    0   12    1.14905    1.09720  4.51%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 10
#   Clique: 22
#   MIR: 10
#   GUB cover: 1
#   Mod-K: 3
#
# Explored 7 nodes (564 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1.14905 1.20461 1.31301 ... 1.81301
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.149051490515e+00, best bound 1.149051490515e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 1e+00]
#   QObjective range [2e-02, 2e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.13487
# Loaded MIP start with objective 1.13487
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 9.148277e-01, 139 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.91483    0   40    1.13487    0.91483  19.4%     -    0s
#      0     0    1.00365    0   57    1.13487    1.00365  11.6%     -    0s
#      0     0    1.01217    0   68    1.13487    1.01217  10.8%     -    0s
#      0     0    1.01217    0   68    1.13487    1.01217  10.8%     -    0s
#      0     0    1.01217    0   68    1.13487    1.01217  10.8%     -    0s
#      0     0    1.01217    0   34    1.13487    1.01217  10.8%     -    0s
#      0     0    1.04031    0   20    1.13487    1.04031  8.33%     -    0s
#      0     0    1.04114    0   14    1.13487    1.04114  8.26%     -    0s
#      0     0    1.05150    0   12    1.13487    1.05150  7.35%     -    0s
#      0     0    1.05535    0   62    1.13487    1.05535  7.01%     -    0s
#      0     0    1.06686    0   56    1.13487    1.06686  5.99%     -    0s
#      0     0    1.06686    0   53    1.13487    1.06686  5.99%     -    0s
#      0     2    1.06686    0   53    1.13487    1.06686  5.99%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 5
#   Clique: 21
#   MIR: 8
#   Zero half: 16
#
# Explored 9 nodes (804 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.13487
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.134872643452e+00, best bound 1.134872643452e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 1e+00]
#   QObjective range [4e-02, 5e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.12069
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 7.680023e-01, 167 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.76800    0   41    1.12069    0.76800  31.5%     -    0s
# H    0     0                       1.0942872    0.78087  28.6%     -    0s
#      0     0    0.95203    0   48    1.09429    0.95203  13.0%     -    0s
#      0     0    0.98880    0   58    1.09429    0.98880  9.64%     -    0s
#      0     0    0.98880    0   58    1.09429    0.98880  9.64%     -    0s
#      0     2    0.98880    0   58    1.09429    0.98880  9.64%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 4
#   Clique: 34
#   MIR: 5
#   Zero half: 14
#
# Explored 139 nodes (1372 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.09429 1.12069
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.094287245122e+00, best bound 1.094287245122e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 8e-01]
#   QObjective range [6e-02, 7e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.03913
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 6.211769e-01, 106 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.62118    0   43    1.03913    0.62118  40.2%     -    0s
#      0     0    0.86874    0   50    1.03913    0.86874  16.4%     -    0s
#      0     0    0.86874    0   48    1.03913    0.86874  16.4%     -    0s
#      0     2    0.86874    0   48    1.03913    0.86874  16.4%     -    0s
# *  240     9               8       1.0264667    1.00799  1.80%   7.5    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 15
#   Clique: 34
#   MIR: 5
#   Inf proof: 1
#   Zero half: 11
#
# Explored 306 nodes (2520 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.02647 1.03913
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.026466708312e+00, best bound 1.026466708312e+00, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 6e-01]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.875397
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 4.743515e-01, 123 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.47435    0   40    0.87540    0.47435  45.8%     -    0s
#      0     0    0.76866    0   56    0.87540    0.76866  12.2%     -    0s
#      0     0    0.76877    0   47    0.87540    0.76877  12.2%     -    0s
#      0     0    0.76877    0   47    0.87540    0.76877  12.2%     -    0s
#      0     2    0.76877    0   45    0.87540    0.76877  12.2%     -    0s
# H   48     4                       0.8637185    0.86372  0.00%  14.4    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 3
#   Clique: 39
#   MIR: 6
#   GUB cover: 2
#   Zero half: 8
#
# Explored 52 nodes (1114 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.863718 0.875397
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.637184933820e-01, best bound 8.637184933820e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 4e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.667385
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 3.275261e-01, 104 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.32753    0   41    0.66739    0.32753  50.9%     -    0s
#      0     0    0.61248    0   56    0.66739    0.61248  8.23%     -    0s
#      0     0    0.64745    0   14    0.66739    0.64745  2.99%     -    0s
#      0     0    0.64745    0   13    0.66739    0.64745  2.99%     -    0s
#      0     0    0.64745    0   14    0.66739    0.64745  2.99%     -    0s
#      0     0    0.66603    0    8    0.66739    0.66603  0.20%     -    0s
#      0     0 infeasible    0         0.66739    0.66739  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 8
#
# Explored 1 nodes (518 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.667385
#
# Optimal solution found (tolerance 1.00e-04)
# ...
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.49129    0   40    0.89143    0.49129  44.9%     -    0s
#      0     0    0.72695    0   53    0.89143    0.72695  18.5%     -    0s
#      0     0    0.72695    0   48    0.89143    0.72695  18.5%     -    0s
#      0     2    0.72695    0   48    0.89143    0.72695  18.5%     -    0s
# H  168    51                       0.8826416    0.82099  6.99%   9.4    0s
# *  202    18              21       0.8377327    0.82099  2.00%   8.9    0s
#
# Cutting planes:
#   Cover: 2
#   Clique: 39
#   MIR: 13
#   GUB cover: 1
#   Zero half: 6
#
# Explored 271 nodes (2670 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.837733 0.882642 0.891431
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.377326781144e-01, best bound 8.377326781144e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-03, 4e-01]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.686663
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 3.444638e-01, 117 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.34446    0   40    0.68666    0.34446  49.8%     -    0s
#      0     0    0.59579    0   60    0.68666    0.59579  13.2%     -    0s
#      0     0    0.60635    0   51    0.68666    0.60635  11.7%     -    0s
#      0     0    0.60635    0   49    0.68666    0.60635  11.7%     -    0s
#      0     2    0.60635    0   50    0.68666    0.60635  11.7%     -    0s
# H    4     4                       0.6684030    0.62521  6.46%  25.5    0s
# H   35    12                       0.6525300    0.63259  3.06%  10.3    0s
#
# Cutting planes:
#   Cover: 5
#   Clique: 28
#   MIR: 7
#   Zero half: 8
#
# Explored 69 nodes (864 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.65253 0.668403 0.686663
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.525299529251e-01, best bound 6.525299529251e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-03, 2e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.456197
# Loaded MIP start with objective 0.456197
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 1.976384e-01, 126 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.19764    0   40    0.45620    0.19764  56.7%     -    0s
#      0     0    0.40086    0   46    0.45620    0.40086  12.1%     -    0s
#      0     0    0.41004    0   20    0.45620    0.41004  10.1%     -    0s
#      0     0    0.41004    0   20    0.45620    0.41004  10.1%     -    0s
#      0     0    0.44216    0   13    0.45620    0.44216  3.08%     -    0s
#      0     0    0.45207    0   20    0.45620    0.45207  0.91%     -    0s
#      0     0     cutoff    0         0.45620    0.45620  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 5
#
# Explored 1 nodes (462 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.456197
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.561967036419e-01, best bound 4.561967036419e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-03, 4e-03]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.259863
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 8.589756e-02, 85 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.08590    0   32    0.25986    0.08590  66.9%     -    0s
#      0     0    0.16749    0   36    0.25986    0.16749  35.5%     -    0s
# H    0     0                       0.2534867    0.18155  28.4%     -    0s
#      0     0    0.18155    0   37    0.25349    0.18155  28.4%     -    0s
#      0     0    0.24599    0   28    0.25349    0.24599  2.96%     -    0s
#      0     0    0.24599    0   37    0.25349    0.24599  2.96%     -    0s
#      0     0     cutoff    0         0.25349    0.25349  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 3
#   Implied bound: 3
#   Clique: 3
#   MIR: 9
#   GUB cover: 1
#   Zero half: 10
#
# Explored 1 nodes (335 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.253487 0.259863
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.534867317904e-01, best bound 2.534867317904e-01, gap 0.0000%
# Optimize a model with 88 rows, 264 columns and 1897 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [5e-03, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.3403
# MIP start did not produce a new incumbent solution
#
# Presolve removed 21 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Variable types: 0 continuous, 159 integer (150 binary)
#
# Root relaxation: objective 7.545639e-01, 121 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.75456    0   34    1.34030    0.75456  43.7%     -    0s
# H    0     0                       1.3114595    0.76220  41.9%     -    0s
#      0     0    0.78320    0   21    1.31146    0.78320  40.3%     -    0s
# H    0     0                       0.9885792    0.78320  20.8%     -    0s
#      0     0    0.79287    0   48    0.98858    0.79287  19.8%     -    0s
# H    0     0                       0.9092141    0.79287  12.8%     -    0s
#      0     0    0.80415    0   42    0.90921    0.80415  11.6%     -    0s
#      0     0    0.80679    0   41    0.90921    0.80679  11.3%     -    0s
#      0     0    0.80837    0   44    0.90921    0.80837  11.1%     -    0s
#      0     0    0.82642    0   47    0.90921    0.82642  9.11%     -    0s
#      0     0    0.82642    0   51    0.90921    0.82642  9.11%     -    0s
#      0     0    0.82860    0   56    0.90921    0.82860  8.87%     -    0s
#      0     0    0.83069    0   51    0.90921    0.83069  8.64%     -    0s
#      0     0    0.83077    0   53    0.90921    0.83077  8.63%     -    0s
#      0     0    0.83593    0   45    0.90921    0.83593  8.06%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 9
#   Clique: 7
# 13.0
# 6.030044722634498
# 34.0
# WebIO.Scope("scope-91b7a904-9d59-451b-96fe-63b16569366f", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"curriculum\":{\"name\":\"University of Kentucky EE Program\",\"dp_name\":\"University of Kentucky EE Program 4-year Plan\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\"EGR 101\",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"Engineering Exploration I\",\"id\":2071595408,\"credits\":1,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"EGR 102\",\"metrics\":{\"centrality\":0,\"complexity\":6.0,\"blocking factor\":3,\"delay factor\":3.0},\"nameSub\":\"Fundamentals of Engineering Computing\",\"id\":502542156,\"credits\":2,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3389674827,\"target_id\":2865398329,\"type\":\"coreq\"}],\"name\":\"PHY 231\",\"metrics\":{\"centrality\":62,\"complexity\":16.0,\"blocking factor\":10,\"delay factor\":6.0},\"nameSub\":\"General University Physics\",\"id\":2865398329,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":2865398329,\"target_id\":746915474,\"type\":\"coreq\"}],\"name\":\"PHY 241\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":0,\"delay factor\":3.0},\"nameSub\":\"General University Physics Lab\",\"id\":746915474,\"credits\":1,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"CIS/WRD 110\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"nameSub\":\"Composition and Communication I\",\"id\":858428248,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"MA 113\",\"metrics\":{\"centrality\":0,\"complexity\":23.0,\"blocking factor\":15,\"delay factor\":8.0},\"nameSub\":\"Calculus I\",\"id\":3389674827,\"credits\":4,\"nameCanonical\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":502542156,\"target_id\":1123828828,\"type\":\"prereq\"},{\"source_id\":3389674827,\"target_id\":1123828828,\"type\":\"coreq\"},{\"source_id\":2865398329,\"target_id\":1123828828,\"type\":\"coreq\"},{\"source_id\":738464693,\"target_id\":1123828828,\"type\":\"coreq\"}],\"name\":\"EGR 103\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":0,\"delay factor\":3.0},\"nameSub\":\"Engineering Exploration II\",\"id\":1123828828,\"credits\":2,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":858428248,\"target_id\":3660518225,\"type\":\"prereq\"}],\"name\":\"CIS/WRD 111\",\"metrics\":{\"centrality\":0,\"complexity\":2.0,\"blocking factor\":0,\"delay factor\":2.0},\"nameSub\":\"Composition and Communication II\",\"id\":3660518225,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3389674827,\"target_id\":2966989896,\"type\":\"prereq\"}],\"name\":\"MA 114\",\"metrics\":{\"centrality\":102,\"complexity\":19.0,\"blocking factor\":11,\"delay factor\":8.0},\"nameSub\":\"Calculus II\",\"id\":2966989896,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"CHE 105\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"nameSub\":\"General College Chemistry I\",\"id\":738464693,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"UK Core - Social Sciences\",\"id\":1586162741,\"credits\":3,\"nameCanonical\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"UK Core -  ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"curriculum"=>Dict{String,Any}("name"=>"University of Kentucky EE Program","dp_name"=>"University of Kentucky EE Program 4-year Plan","curriculum_terms"=>Dict{String,Any}[Dict("name"=>"Term 1","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"EGR 101","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"Engineering Exploration I","id"=>2071595408,"credits"=>1,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"EGR 102","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>6.0,"blocking factor"=>3,"delay factor"=>3.0),"nameSub"=>"Fundamentals of Engineering Computing","id"=>502542156,"credits"=>2,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>3389674827,"target_id"=>2865398329,"type"=>"coreq")],"name"=>"PHY 231","metrics"=>Dict{String,Any}("centrality"=>62,"complexity"=>16.0,"blocking factor"=>10,"delay factor"=>6.0),"nameSub"=>"General University Physics","id"=>2865398329,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>2865398329,"target_id"=>746915474,"type"=>"coreq")],"name"=>"PHY 241","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>0,"delay factor"=>3.0),"nameSub"=>"General University Physics Lab","id"=>746915474,"credits"=>1,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"CIS/WRD 110","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"nameSub"=>"Composition and Communication I","id"=>858428248,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"MA 113","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>23.0,"blocking factor"=>15,"delay factor"=>8.0),"nameSub"=>"Calculus I","id"=>3389674827,"credits"=>4,"nameCanonical"=>"")],"id"=>1), Dict("name"=>"Term 2","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>502542156,"target_id"=>1123828828,"type"=>"prereq"), Dict("source_id"=>3389674827,"target_id"=>1123828828,"type"=>"coreq"), Dict("source_id"=>2865398329,"target_id"=>1123828828,"type"=>"coreq"), Dict("source_id"=>738464693,"target_id"=>1123828828,"type"=>"coreq")],"name"=>"EGR 103","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>0,"delay factor"=>3.0),"nameSub"=>"Engineering Exploration II","id"=>1123828828,"credits"=>2,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>858428248,"target_id"=>3660518225,"type"=>"prereq")],"name"=>"CIS/WRD 111","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>2.0,"blocking factor"=>0,"delay factor"=>2.0),"nameSub"=>"Composition and Communication II","id"=>3660518225,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>3389674827,"target_id"=>2966989896,"type"=>"prereq")],"name"=>"MA 114","metrics"=>Dict{String,Any}("centrality"=>102,"complexity"=>19.0,"blocking factor"=>11,"delay factor"=>8.0),"nameSub"=>"Calculus II","id"=>2966989896,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"CHE 105","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"nameSub"=>"General College Chemistry I","id"=>738464693,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"UK Core - Social Sciences","id"=>1586162741,"credits"=>3,"nameCanonical"=>"")],"id"=>2), Dict("name"=>"Term 3","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0 ...
