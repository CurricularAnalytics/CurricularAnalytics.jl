# %%
if split(pwd(),Base.Filesystem.path_separator)[end] != "CurricularAnalytics.jl"
    cd("../..")
end
println("Current directory: " * split(pwd(),Base.Filesystem.path_separator)[end])
using Pkg
pkg"activate ."
using CurricularAnalytics
# Out:
# Current directory: CurricularAnalytics.jl
# ┌ Info: Recompiling stale cache file /Users/heileman/.julia/compiled/v1.0/CurricularAnalytics/pJfqI.ji for CurricularAnalytics [593ffa3d-269e-5d81-88bc-c3b6809c35a6]
# └ @ Base loading.jl:1184
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/41794c50334d4e214c4ed8746cf62efbfa8785f6-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/41794c50334d4e214c4ed8746cf62efbfa8785f6-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")

# %%
using CSV
using DataFrames
include("src/Optimization.jl")
optimize_plan("examples/Notebooks/Opt_Configurations.csv", "examples/UKY_EE_partial.csv",
    "examples/Notebooks/CourseCombinationsWithCond.csv")
# Out:
# Number of courses in curriculum: 32
# Total credit hours: 131
# Dict{Any,Any}(4=>19,2=>19,3=>19,5=>19,6=>10,1=>15)
# 15
# Academic license - for non-commercial use only
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Variable types: 0 continuous, 159 integer (150 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 1.250000e+01, 71 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.50000    0   14   14.00000   12.50000  10.7%     -    0s
# H    0     0                      13.0000000   12.50000  3.85%     -    0s
#
# Explored 1 nodes (144 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 13 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [4e+00, 4e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 21.9142
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 0.000000e+00, 81 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   30   21.91417    0.00000   100%     -    0s
# H    0     0                      14.0529635    0.00000   100%     -    0s
# H    0     0                      12.0505885    0.00000   100%     -    0s
#      0     0    2.04119    0   31   12.05059    2.04119  83.1%     -    0s
# H    0     0                       8.0603890    2.04119  74.7%     -    0s
#      0     0    2.04119    0   36    8.06039    2.04119  74.7%     -    0s
#      0     0    4.08237    0   14    8.06039    4.08237  49.4%     -    0s
# H    0     0                       6.0300447    4.08237  32.3%     -    0s
#      0     0    4.08237    0   16    6.03004    4.08237  32.3%     -    0s
#      0     0    6.01491    0    8    6.03004    6.01491  0.25%     -    0s
#      0     0    6.01491    0   16    6.03004    6.01491  0.25%     -    0s
#      0     0    6.01491    0   15    6.03004    6.01491  0.25%     -    0s
#      0     0     cutoff    0         6.03004    6.03004  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 2
#   StrongCG: 1
#   Zero half: 3
#
# Explored 1 nodes (523 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 6.03004 8.06039 12.0506 ... 21.9142
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.030044722634e+00, best bound 6.030044722634e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 34
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 151 columns, 480 nonzeros
# Variable types: 0 continuous, 151 integer (150 binary)
#
# Root relaxation: objective 1.730769e+01, 85 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.30769    0   25   34.00000   17.30769  49.1%     -    0s
# H    0     0                      33.0000000   17.30769  47.6%     -    0s
# H    0     0                      25.0000000   17.30769  30.8%     -    0s
# H    0     0                      24.0000000   17.30769  27.9%     -    0s
#      0     0   18.00000    0   15   24.00000   18.00000  25.0%     -    0s
#      0     0   18.10714    0   41   24.00000   18.10714  24.6%     -    0s
#      0     0   18.13333    0   41   24.00000   18.13333  24.4%     -    0s
#      0     0   18.52456    0   49   24.00000   18.52456  22.8%     -    0s
#      0     0   18.63415    0   45   24.00000   18.63415  22.4%     -    0s
# H    0     0                      22.0000000   18.63415  15.3%     -    0s
#      0     0   19.00000    0   46   22.00000   19.00000  13.6%     -    0s
# H    0     0                      20.0000000   19.00000  5.00%     -    0s
#      0     0   19.00000    0   40   20.00000   19.00000  5.00%     -    0s
#      0     0   19.00000    0   45   20.00000   19.00000  5.00%     -    0s
#      0     0   19.00000    0   47   20.00000   19.00000  5.00%     -    0s
#      0     0     cutoff    0        20.00000   20.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 8
#   Clique: 4
#   MIR: 7
#   GUB cover: 1
#   Zero half: 1
#   Mod-K: 3
#
# Explored 1 nodes (274 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 20 22 24 ... 34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [6e-02, 2e+00]
#   QObjective range [2e-02, 2e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.41439
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 1.174236e+00, 135 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.17424    0   38    1.41439    1.17424  17.0%     -    0s
#      0     0    1.27473    0   52    1.41439    1.27473  9.87%     -    0s
#      0     0    1.27473    0   51    1.41439    1.27473  9.87%     -    0s
#      0     2    1.27473    0   51    1.41439    1.27473  9.87%     -    0s
#
# Cutting planes:
#   Cover: 1
#   Clique: 34
#   MIR: 5
#   Zero half: 9
#
# Explored 107 nodes (1106 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.41439
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.414392581508e+00, best bound 1.414392581508e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [6e-02, 1e+00]
#   QObjective range [4e-02, 5e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.40021
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 1.027778e+00, 106 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.02778    0   32    1.40021    1.02778  26.6%     -    0s
# H    0     0                       1.3896802    1.02778  26.0%     -    0s
#      0     0    1.22726    0   39    1.38968    1.22726  11.7%     -    0s
#      0     0    1.22726    0   37    1.38968    1.22726  11.7%     -    0s
#      0     2    1.22726    0   37    1.38968    1.22726  11.7%     -    0s
#
# Cutting planes:
#   Cover: 4
#   Clique: 39
#   MIR: 12
#   GUB cover: 1
#   Zero half: 4
#
# Explored 46 nodes (802 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.38968 1.40021
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.389680199052e+00, best bound 1.389680199052e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [5e-02, 1e+00]
#   QObjective range [6e-02, 7e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.33452
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 8.809524e-01, 110 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.88095    0   32    1.33452    0.88095  34.0%     -    0s
#      0     0    1.14447    0   41    1.33452    1.14447  14.2%     -    0s
#      0     0    1.14447    0   37    1.33452    1.14447  14.2%     -    0s
#      0     2    1.14447    0   37    1.33452    1.14447  14.2%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 7
#   Clique: 39
#   MIR: 10
#   GUB cover: 2
#   Zero half: 3
#
# Explored 59 nodes (1037 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.33452
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.334520298578e+00, best bound 1.334520298578e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-02, 1e+00]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.27936
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 7.341270e-01, 122 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.73413    0   33    1.27936    0.73413  42.6%     -    0s
#      0     0    1.06024    0   39    1.27936    1.06024  17.1%     -    0s
#      0     0    1.06024    0   39    1.27936    1.06024  17.1%     -    0s
#      0     2    1.06024    0   39    1.27936    1.06024  17.1%     -    0s
# *  116     1              14       1.2528654    1.24641  0.52%  10.4    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 9
#   Clique: 39
#   MIR: 5
#   GUB cover: 1
#   Zero half: 9
#
# Explored 120 nodes (1560 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.25287 1.27936
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.252865405895e+00, best bound 1.252865405895e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-02, 8e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.1018
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 5.873016e-01, 96 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.58730    0   33    1.10180    0.58730  46.7%     -    0s
#      0     0    0.97194    0   52    1.10180    0.97194  11.8%     -    0s
#      0     0    1.00369    0   46    1.10180    1.00369  8.90%     -    0s
#      0     0    1.00369    0   46    1.10180    1.00369  8.90%     -    0s
#      0     2    1.00369    0   46    1.10180    1.00369  8.90%     -    0s
# H   19     8                       1.0897623    1.05802  2.91%  11.8    0s
#
# Cutting planes:
#   Cover: 5
#   Clique: 18
#   MIR: 5
#   Zero half: 10
#
# Explored 42 nodes (829 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.08976 1.1018
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.089762325012e+00, best bound 1.089762325012e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [2e-02, 6e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.893429
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 4.404762e-01, 95 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.44048    0   31    0.89343    0.44048  50.7%     -    0s
#      0     0    0.81600    0   48    0.89343    0.81600  8.67%     -    0s
#      0     0    0.83330    0   40    0.89343    0.83330  6.73%     -    0s
#      0     0    0.85012    0   14    0.89343    0.85012  4.85%     -    0s
#      0     0    0.85012    0   14    0.89343    0.85012  4.85%     -    0s
#      0     0    0.86962    0    6    0.89343    0.86962  2.66%     -    0s
#      0     0 infeasible    0         0.89343    0.89343  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   MIR: 1
#   StrongCG: 1
#
# Explored 1 nodes (483 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.893429
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.934290757292e-01, best bound 8.934290757292e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [2e-02, 4e-01]
#   QObjective range [1e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.697096
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 2.936508e-01, 81 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.29365    0   30    0.69710    0.29365  57.9%     -    0s
#      0     0    0.62875    0   38    0.69710    0.62875  9.80%     -    0s
#      0     0    0.68122    0    8    0.69710    0.68122  2.28%     -    0s
#      0     0    0.68122    0    8    0.69710    0.68122  2.28%     -    0s
#      0     0 infeasible    0         0.69710    0.69710  0.00%     -    0s
#
# Explored 1 nodes (308 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.697096
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.970958264460e-01, best bound 6.970958264460e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [8e-03, 2e-01]
#   QObjective range [2e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.500763
# MIP start did not produce a new incumbent solution
#
# Presolve removed 37 rows and 113 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 241 columns, 753 nonzeros
# Variable types: 0 continuous, 241 integer (240 binary)
#
# Root relaxation: objective 1.468254e-01, 84 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.14683    0   32    0.50076    0.14683  70.7%     -    0s
#      0     0    0.41921    0   16    0.50076    0.41921  16.3%     -    0s
#      0     0    0.46016    0   39    0.50076    0.46016  8.11%     -    0s
#      0     0    0.49283    0    4    0.50076    0.49283  1.58%     -    0s
#      0     0    0.49283    0   14    0.50076    0.49283  1.58%     -    0s
#      0     0 infeasible    0         0.50076    0.50076  0.00%     -    0s
#
# Cutting planes:
#   Cover: 4
#   MIR: 4
#
# Explored 1 nodes (451 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.500763
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.007625771627e-01, best bound 5.007625771627e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 2e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.97
# Loaded MIP start with objective 1.86024
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Found heuristic solution: objective 1.8602400
# Variable types: 0 continuous, 159 integer (150 binary)
#
# Root relaxation: objective 1.115839e+00, 132 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.11584    0   33    1.86024    1.11584  40.0%     -    0s
#      0     0    1.15979    0   21    1.86024    1.15979  37.7%     -    0s
# H    0     0                       1.6711189    1.15979  30.6%     -    0s
# H    0     0                       1.4779326    1.15979  21.5%     -    0s
#      0     0    1.16014    0   17    1.47793    1.16014  21.5%     -    0s
#      0     0    1.19495    0   41    1.47793    1.19495  19.1%     -    0s
#      0     0    1.19675    0   40    1.47793    1.19675  19.0%     -    0s
#      0     0    1.20046    0   47    1.47793    1.20046  18.8%     -    0s
# H    0     0                       1.4157956    1.20046  15.2%     -    0s
# H    0     0                       1.3523035    1.20046  11.2%     -    0s
#      0     0    1.20068    0   45    1.35230    1.20068  11.2%     -    0s
#      0     0    1.20703    0   48    1.35230    1.20703  10.7%     -    0s
#      0     0    1.20956    0   48    1.35230    1.20956  10.6%     -    0s
#      0     0    1.22125    0   57    1.35230    1.22125  9.69%     -    0s
#      0     0    1.22125    0   58    1.35230    1.22125  9.69%     -    0s
# H    0     0                       1.2888115    1.22125  5.24%     -    0s
#      0     0    1.22125    0   51    1.28881    1.22125  5.24%     -    0s
#      0     0    1.22686    0   48    1.28881    1.22686  4.81%     -    0s
#      0     0    1.22928    0   53    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   56    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   57    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   57    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   58    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   49    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   14    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   14    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   21    1.28881    1.22928  4.62%     -    0s
#      0     0    1.22928    0   25    1.28881    1.22928  4.62%     -    0s
#      0     0    1.23167    0   26    1.28881    1.23167  4.43%     -    0s
#      0     0    1.23986    0   31    1.28881    1.23986  3.80%     -    0s
#      0     0    1.24078    0   33    1.28881    1.24078  3.73%     -    0s
#      0     0    1.24515    0   21    1.28881    1.24515  3.39%     -    0s
#      0     0    1.24524    0   26    1.28881    1.24524  3.38%     -    0s
#      0     0    1.24862    0   28    1.28881    1.24862  3.12%     -    0s
#      0     0    1.24999    0   21    1.28881    1.24999  3.01%     -    0s
#      0     0    1.25012    0   32    1.28881    1.25012  3.00%     -    0s
#      0     0    1.25061    0   28    1.28881    1.25061  2.96%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 2
#   Clique: 4
#   MIR: 8
#   StrongCG: 2
#   GUB cover: 4
#   Mod-K: 2
#
# Explored 1 nodes (851 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1.28881 1.3523 1.4158 ... 1.96458
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.288811459543e+00, best bound 1.288811459543e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [2e-02, 2e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.27463
# Loaded MIP start with objective 1.27463
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 1.044715e+00, 148 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.04472    0   39    1.27463    1.04472  18.0%     -    0s
#      0     0    1.14485    0   64    1.27463    1.14485  10.2%     -    0s
#      0     0    1.14485    0   59    1.27463    1.14485  10.2%     -    0s
#      0     2    1.15048    0   60    1.27463    1.15048  9.74%     -    0s
#
# Cutting planes:
#   Cover: 7
#   Clique: 27
#   MIR: 5
#   GUB cover: 1
#   Inf proof: 1
#   Zero half: 11
#
# Explored 108 nodes (1063 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.27463
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.274632612480e+00, best bound 1.274632612480e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [4e-02, 5e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.26045
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 8.978901e-01, 152 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.89789    0   41    1.26045    0.89789  28.8%     -    0s
#      0     0    1.08944    0   51    1.26045    1.08944  13.6%     -    0s
#      0     0    1.10831    0   62    1.26045    1.10831  12.1%     -    0s
#      0     0    1.10831    0   62    1.26045    1.10831  12.1%     -    0s
#      0     2    1.10831    0   61    1.26045    1.10831  12.1%     -    0s
# *   35     0              10       1.2419837    1.24198  0.00%  13.4    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 6
#   Clique: 39
#   MIR: 12
#   GUB cover: 1
#   Zero half: 2
#
# Explored 36 nodes (891 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.24198 1.26045
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.241983722087e+00, best bound 1.241983722087e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [6e-02, 7e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.18682
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 7.510647e-01, 150 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.75106    0   41    1.18682    0.75106  36.7%     -    0s
#      0     0    1.00715    0   55    1.18682    1.00715  15.1%     -    0s
#      0     0    1.00715    0   50    1.18682    1.00715  15.1%     -    0s
#      0     2    1.00715    0   50    1.18682    1.00715  15.1%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Clique: 39
#   MIR: 7
#   Zero half: 12
#
# Explored 29 nodes (984 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.18682
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.186823821613e+00, best bound 1.186823821613e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 8e-01]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.13166
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 6.042393e-01, 160 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.60424    0   41    1.13166    0.60424  46.6%     -    0s
#      0     0    0.91845    0   49    1.13166    0.91845  18.8%     -    0s
#      0     0    0.91845    0   49    1.13166    0.91845  18.8%     -    0s
#      0     2    0.91845    0   49    1.13166    0.91845  18.8%     -    0s
# *  185    51              14       1.0866859    1.04113  4.19%   8.4    0s
# *  233     5              11       1.0749070    1.04181  3.08%   9.2    0s
# H  244     2                       1.0641314    1.04181  2.10%   9.4    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 6
#   Clique: 46
#   MIR: 5
#   GUB cover: 1
#   Inf proof: 1
#   Zero half: 14
#
# Explored 281 nodes (3252 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1.06413 1.07491 1.08669 1.13166
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.064131375697e+00, best bound 1.064131375697e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 6e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.913062
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 4.574139e-01, 120 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.45741    0   40    0.91306    0.45741  49.9%     -    0s
#      0     0    0.79747    0   60    0.91306    0.79747  12.7%     -    0s
#      0     0    0.82291    0   50    0.91306    0.82291  9.87%     -    0s
#      0     0    0.82291    0   50    0.91306    0.82291  9.87%     -    0s
#      0     2    0.82291    0   49    0.91306    0.82291  9.87%     -    0s
# *  110    17              20       0.9006534    0.85341  5.25%   8.1    0s
# *  167     3              12       0.8785738    0.87102  0.86%   8.0    0s
#
# Cutting planes:
#   Cover: 6
#   Clique: 28
#   MIR: 5
#   Zero half: 8
#
# Explored 180 nodes (1808 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.878574 0.900653 0.913062
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.785737845556e-01, best bound 8.785737845556e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 4e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.682241
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 3.105885e-01, 110 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.31059    0   39    0.68224    0.31059  54.5%     -    0s
#      0     0    0.62191    0   48    0.68224    0.62191  8.84%     -    0s
#      0     0    0.66433    0   13    0.68224    0.66433  2.62%     -    0s
#      0     0    0.66433    0   13    0.68224    0.66433  2.62%     -    0s
#      0     0    0.66433    0   12    0.68224    0.66433  2.62%     -    0s
#      0     0    0.68156    0    8    0.68224    0.68156  0.10%     -    0s
#      0     0    0.68156    0    6    0.68224    0.68156  0.10%     -    0s
#      0     0 infeasible    0         0.68224    0.68224  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   MIR: 12
#
# Explored 1 nodes (534 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.682241
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.822405352724e-01, best bound 6.822405352724e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 2e-01]
#   QObjective range [1e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.485907
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 1.637631e-01, 131 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.16376    0   40    0.48591    0.16376  66.3%     -    0s
#      0     0    0.41351    0   30    0.48591    0.41351  14.9%     -    0s
#      0     0    0.41418    0   25    0.48591    0.41418  14.8%     -    0s
#      0     0    0.44820    0   36    0.48591    0.44820  7.76%     -    0s
#      0     0    0.47594    0   15    0.48591    0.47594  2.05%     -    0s
#      0     0    0.47860    0   18    0.48591    0.47860  1.50%     -    0s
#      0     0    0.47945    0   23    0.48591    0.47945  1.33%     -    0s
#      0     0    0.48500    0    8    0.48591    0.48500  0.19%     -    0s
#
# Explored 1 nodes (627 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.485907
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.859072859891e-01, best bound 4.859072859891e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e-03, 1e-03]
#   QObjective range [2e-01, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.289574
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 6.371708e-02, 85 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.06372    0   31    0.28957    0.06372  78.0%     -    0s
#      0     0    0.17273    0   39    0.28957    0.17273  40.3%     -    0s
# H    0     0                       0.2878468    0.17273  40.0%     -    0s
# H    0     0                       0.2851368    0.17273  39.4%     -    0s
#      0     0    0.17273    0   43    0.28514    0.17273  39.4%     -    0s
#      0     0    0.24171    0   25    0.28514    0.24171  15.2%     -    0s
#      0     0    0.25586    0   30    0.28514    0.25586  10.3%     -    0s
#      0     0    0.28446    0   45    0.28514    0.28446  0.24%     -    0s
#      0     0    0.28446    0   25    0.28514    0.28446  0.24%     -    0s
#      0     0    0.28446    0   14    0.28514    0.28446  0.24%     -    0s
#      0     0    0.28487    0   23    0.28514    0.28487  0.10%     -    0s
#      0     0     cutoff    0         0.28514    0.28514  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 2
#   Implied bound: 1
#   Clique: 1
#   MIR: 6
#   StrongCG: 1
#   Zero half: 1
#
# Explored 1 nodes (537 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.285137 0.287847 0.289574
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.851367805986e-01, best bound 2.851367805986e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.92412
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Variable types: 0 continuous, 159 integer (150 binary)
#
# Root relaxation: objective 9.954138e-01, 125 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99541    0   33    1.92412    0.99541  48.3%     -    0s
#      0     0    1.03388    0   23    1.92412    1.03388  46.3%     -    0s
# H    0     0                       1.3130081    1.03388  21.3%     -    0s
#      0     0    1.03457    0   16    1.31301    1.03457  21.2%     -    0s
#      0     0    1.06433    0   42    1.31301    1.06433  18.9%     -    0s
#      0     0    1.06778    0   42    1.31301    1.06778  18.7%     -    0s
#      0     0    1.06815    0   42    1.31301    1.06815  18.6%     -    0s
# H    0     0                       1.2046070    1.06815  11.3%     -    0s
#      0     0    1.07470    0   53    1.20461    1.07470  10.8%     -    0s
#      0     0    1.07470    0   53    1.20461    1.07470  10.8%     -    0s
#      0     0    1.08446    0   45    1.20461    1.08446  10.0%     -    0s
#      0     0    1.08635    0   47    1.20461    1.08635  9.82%     -    0s
#      0     0    1.08935    0   50    1.20461    1.08935  9.57%     -    0s
#      0     0    1.08935    0   50    1.20461    1.08935  9.57%     -    0s
#      0     0    1.09303    0   49    1.20461    1.09303  9.26%     -    0s
#      0     0    1.09407    0   51    1.20461    1.09407  9.18%     -    0s
# H    0     0                       1.1490515    1.09407  4.79%     -    0s
#      0     0    1.09407    0   51    1.14905    1.09407  4.79%     -    0s
#      0     0    1.09478    0   53    1.14905    1.09478  4.72%     -    0s
#      0     0    1.09478    0   52    1.14905    1.09478  4.72%     -    0s
#      0     2    1.09478    0   51    1.14905    1.09478  4.72%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 10
#   Clique: 32
#   MIR: 15
#   GUB cover: 2
#   Mod-K: 4
#
# Explored 9 nodes (642 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1.14905 1.20461 1.31301 1.92412
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.149051490515e+00, best bound 1.149051490515e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 1e+00]
#   QObjective range [2e-02, 2e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.13487
# Loaded MIP start with objective 1.13487
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 9.148277e-01, 139 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.91483    0   40    1.13487    0.91483  19.4%     -    0s
#      0     0    1.01652    0   61    1.13487    1.01652  10.4%     -    0s
#      0     0    1.01652    0   56    1.13487    1.01652  10.4%     -    0s
#      0     2    1.01652    0   56    1.13487    1.01652  10.4%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 8
#   Clique: 32
#   MIR: 15
#   GUB cover: 1
#   Zero half: 4
#
# Explored 77 nodes (1239 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.13487
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.134872643452e+00, best bound 1.134872643452e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 1e+00]
#   QObjective range [4e-02, 5e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.12069
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 7.680023e-01, 167 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.76800    0   40    1.12069    0.76800  31.5%     -    0s
# H    0     0                       1.0942872    0.78087  28.6%     -    0s
#      0     0    0.95161    0   50    1.09429    0.95161  13.0%     -    0s
#      0     0    0.97594    0   57    1.09429    0.97594  10.8%     -    0s
#      0     0    0.97594    0   57    1.09429    0.97594  10.8%     -    0s
#      0     2    0.97594    0   57    1.09429    0.97594  10.8%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 9
#   Clique: 39
#   MIR: 5
#   GUB cover: 1
#   Zero half: 10
#
# Explored 29 nodes (780 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.09429 1.12069
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.094287245122e+00, best bound 1.094287245122e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 8e-01]
#   QObjective range [6e-02, 7e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.03913
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 6.211769e-01, 106 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.62118    0   41    1.03913    0.62118  40.2%     -    0s
#      0     0    0.86874    0   51    1.03913    0.86874  16.4%     -    0s
#      0     0    0.86874    0   48    1.03913    0.86874  16.4%     -    0s
#      0     2    0.86874    0   48    1.03913    0.86874  16.4%     -    0s
# *  169     5               8       1.0275096    1.01511  1.21%   7.3    0s
# *  189     0               7       1.0264667    1.02346  0.29%   7.6    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 11
#   Clique: 39
#   MIR: 11
#   GUB cover: 1
#   Inf proof: 1
#   Zero half: 7
#
# Explored 213 nodes (1953 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1.02647 1.02751 1.03913
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.026466708312e+00, best bound 1.026466708312e+00, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 6e-01]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.875397
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 4.743515e-01, 123 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.47435    0   41    0.87540    0.47435  45.8%     -    0s
#      0     0    0.76866    0   54    0.87540    0.76866  12.2%     -    0s
#      0     0    0.79873    0   53    0.87540    0.79873  8.76%     -    0s
#      0     0    0.79873    0   53    0.87540    0.79873  8.76%     -    0s
#      0     2    0.79873    0   53    0.87540    0.79873  8.76%     -    0s
# H   33     9                       0.8637185    0.83584  3.23%  13.1    0s
#
# Cutting planes:
#   Cover: 7
#   Clique: 22
#   MIR: 5
#   GUB cover: 2
#   Zero half: 9
#
# Explored 83 nodes (1244 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.863718 0.875397
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.637184933820e-01, best bound 8.637184933820e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 4e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.667385
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 3.275261e-01, 104 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.32753    0   40    0.66739    0.32753  50.9%     -    0s
#      0     0    0.61154    0   53    0.66739    0.61154  8.37%     -    0s
#      0     0    0.64754    0   21    0.66739    0.64754  2.97%     -    0s
#      0     0    0.64754    0   19    0.66739    0.64754  2.97%     -    0s
#      0     0    0.64754    0   12    0.66739    0.64754  2.97%     -    0s
#      0     0    0.66603    0    6    0.66739    0.66603  0.20%     -    0s
#      0     0 infeasible    0         0.66739    0.66739  0.00%     -    0s
#      0     0 infeasible    0         0.66739    0.66739  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 9
#
# Explored 1 nodes (544 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.667385
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.673852440988e-01, best bound 6.673852440988e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [3e-03, 2e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.471052
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 1.807007e-01, 91 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.18070    0   40    0.47105    0.18070  61.6%     -    0s
#      0     0    0.40770    0   42    0.47105    0.40770  13.4%     -    0s
#      0     0    0.45905    0   15    0.47105    0.45905  2.55%     -    0s
#      0     0    0.45905    0   15    0.47105    0.45905  2.55%     -    0s
#      0     0    0.45905    0   13    0.47105    0.45905  2.55%     -    0s
#      0     0    0.46970    0   10    0.47105    0.46970  0.29%     -    0s
#      0     0 infeasible    0         0.47105    0.47105  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 4
#
# Explored 1 nodes (409 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.471052
#
# ...
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-03, 4e-01]
#   QObjective range [8e-02, 9e-02]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.686663
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 3.444638e-01, 117 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.34446    0   41    0.68666    0.34446  49.8%     -    0s
#      0     0    0.59481    0   60    0.68666    0.59481  13.4%     -    0s
#      0     0    0.59481    0   56    0.68666    0.59481  13.4%     -    0s
#      0     0    0.59481    0   56    0.68666    0.59481  13.4%     -    0s
#      0     2    0.59481    0   56    0.68666    0.59481  13.4%     -    0s
# H   20    10                       0.6640380    0.63056  5.04%  16.6    0s
# H   86     5                       0.6525300    0.63666  2.43%   8.2    0s
#
# Cutting planes:
#   Cover: 5
#   Clique: 33
#   MIR: 6
#   GUB cover: 2
#   Zero half: 10
#
# Explored 107 nodes (1198 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.65253 0.664038 0.686663
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.525299529251e-01, best bound 6.525299529251e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-03, 2e-01]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.456197
# Loaded MIP start with objective 0.456197
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 1.976384e-01, 126 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.19764    0   40    0.45620    0.19764  56.7%     -    0s
#      0     0    0.40086    0   51    0.45620    0.40086  12.1%     -    0s
#      0     0    0.41004    0   20    0.45620    0.41004  10.1%     -    0s
#      0     0    0.41004    0   20    0.45620    0.41004  10.1%     -    0s
#      0     0    0.44216    0   12    0.45620    0.44216  3.08%     -    0s
#      0     0    0.45039    0   19    0.45620    0.45039  1.27%     -    0s
#      0     0     cutoff    0         0.45620    0.45620  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 6
#
# Explored 1 nodes (424 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.456197
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.561967036419e-01, best bound 4.561967036419e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Model has 180 quadratic objective terms
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [4e-03, 4e-03]
#   QObjective range [1e-01, 1e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 0.259863
# MIP start did not produce a new incumbent solution
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 157 rows, 249 columns, 870 nonzeros
# Variable types: 0 continuous, 249 integer (240 binary)
#
# Root relaxation: objective 8.589756e-02, 85 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.08590    0   31    0.25986    0.08590  66.9%     -    0s
#      0     0    0.18155    0   39    0.25986    0.18155  30.1%     -    0s
# H    0     0                       0.2575518    0.18155  29.5%     -    0s
#      0     0    0.25045    0   41    0.25755    0.25045  2.76%     -    0s
# H    0     0                       0.2534867    0.25045  1.20%     -    0s
#      0     0    0.25045    0   27    0.25349    0.25045  1.20%     -    0s
#      0     0    0.25045    0   27    0.25349    0.25045  1.20%     -    0s
#      0     0    0.25045    0   44    0.25349    0.25045  1.20%     -    0s
#      0     0    0.25045    0   26    0.25349    0.25045  1.20%     -    0s
#      0     0    0.25045    0   29    0.25349    0.25045  1.20%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   MIR: 2
#   StrongCG: 1
#   Zero half: 3
#
# Explored 1 nodes (523 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.253487 0.257552 0.259863
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.534867317904e-01, best bound 2.534867317904e-01, gap 0.0000%
# Optimize a model with 94 rows, 264 columns and 2155 nonzeros
# Variable types: 6 continuous, 258 integer (258 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [5e-03, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start with objective 1.41967
# Loaded MIP start with objective 1.41967
#
# Presolve removed 27 rows and 105 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 159 columns, 599 nonzeros
# Variable types: 0 continuous, 159 integer (150 binary)
#
# Root relaxation: objective 7.545639e-01, 121 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.75456    0   33    1.41967    0.75456  46.8%     -    0s
# H    0     0                       1.3457220    0.75456  43.9%     -    0s
# H    0     0                       1.2266744    0.75456  38.5%     -    0s
# H    0     0                       1.0282617    0.77294  24.8%     -    0s
#      0     0    0.78204    0   21    1.02826    0.78204  23.9%     -    0s
#      0     0    0.78475    0   13    1.02826    0.78475  23.7%     -    0s
#      0     0    0.80134    0   42    1.02826    0.80134  22.1%     -    0s
#      0     0    0.80747    0   38    1.02826    0.80747  21.5%     -    0s
#      0     0    0.80856    0   35    1.02826    0.80856  21.4%     -    0s
#      0     0    0.80856    0   42    1.02826    0.80856  21.4%     -    0s
# H    0     0                       0.9092141    0.80856  11.1%     -    0s
#      0     0    0.82446    0   48    0.90921    0.82446  9.32%     -    0s
#      0     0    0.82446    0   48    0.90921    0.82446  9.32%     -    0s
#      0     0    0.82717    0   22    0.90921    0.82717  9.02%     -    0s
#      0     0    0.83069    0   53    0.90921    0.83069  8.64%     -    0s
#      0     0    0.83069    0   57    0.90921    0.83069  8.64%     -    0s
#      0     0    0.83069    0   57    0.90921    0.83069  8.64%     -    0s
#      0     0    0.83593    0   48    0.90921    0.83593  8.06%     -    0s
#      0     0    0.83687    0   47    0.90921    0.83687  7.96%     -    0s
#      0     0    0.83711    0   51    0.90921    0.83711  7.93%     -    0s
#      0     0    0.83711    0   51    0.90921    0.83711  7.93%     -    0s
#      0     0    0.83873    0   51    0.90921    0.83873  7.75%     -    0s
#      0     0    0.83896    0   50    0.90921    0.83896  7.73%     -    0s
#      0     0    0.83896    0   52    0.90921    0.83896  7.73%     -    0s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 13
#   Clique: 47
#   MIR: 13
# 13.0
# 6.030044722634498
# 34.0
# WebIO.Scope("scope-e611aad6-964e-42da-9962-e5be63d5815a", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"curriculum\":{\"name\":\"University of Kentucky EE Program\",\"dp_name\":\"University of Kentucky EE Program 4-year Plan\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\"EGR 101\",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"Engineering Exploration I\",\"id\":2071595408,\"credits\":1,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"EGR 102\",\"metrics\":{\"centrality\":0,\"complexity\":6.0,\"blocking factor\":3,\"delay factor\":3.0},\"nameSub\":\"Fundamentals of Engineering Computing\",\"id\":502542156,\"credits\":2,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3389674827,\"target_id\":2865398329,\"type\":\"coreq\"}],\"name\":\"PHY 231\",\"metrics\":{\"centrality\":62,\"complexity\":16.0,\"blocking factor\":10,\"delay factor\":6.0},\"nameSub\":\"General University Physics\",\"id\":2865398329,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":2865398329,\"target_id\":746915474,\"type\":\"coreq\"}],\"name\":\"PHY 241\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":0,\"delay factor\":3.0},\"nameSub\":\"General University Physics Lab\",\"id\":746915474,\"credits\":1,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"CIS/WRD 110\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"nameSub\":\"Composition and Communication I\",\"id\":858428248,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"MA 113\",\"metrics\":{\"centrality\":0,\"complexity\":23.0,\"blocking factor\":15,\"delay factor\":8.0},\"nameSub\":\"Calculus I\",\"id\":3389674827,\"credits\":4,\"nameCanonical\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":502542156,\"target_id\":1123828828,\"type\":\"prereq\"},{\"source_id\":3389674827,\"target_id\":1123828828,\"type\":\"coreq\"},{\"source_id\":2865398329,\"target_id\":1123828828,\"type\":\"coreq\"},{\"source_id\":738464693,\"target_id\":1123828828,\"type\":\"coreq\"}],\"name\":\"EGR 103\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":0,\"delay factor\":3.0},\"nameSub\":\"Engineering Exploration II\",\"id\":1123828828,\"credits\":2,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":858428248,\"target_id\":3660518225,\"type\":\"prereq\"}],\"name\":\"CIS/WRD 111\",\"metrics\":{\"centrality\":0,\"complexity\":2.0,\"blocking factor\":0,\"delay factor\":2.0},\"nameSub\":\"Composition and Communication II\",\"id\":3660518225,\"credits\":3,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3389674827,\"target_id\":2966989896,\"type\":\"prereq\"}],\"name\":\"MA 114\",\"metrics\":{\"centrality\":102,\"complexity\":19.0,\"blocking factor\":11,\"delay factor\":8.0},\"nameSub\":\"Calculus II\",\"id\":2966989896,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\"CHE 105\",\"metrics\":{\"centrality\":0,\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"nameSub\":\"General College Chemistry I\",\"id\":738464693,\"credits\":4,\"nameCanonical\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"centrality\":0,\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"nameSub\":\"UK Core - Social Sciences\",\"id\":1586162741,\"credits\":3,\"nameCanonical\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":502542156,\"target_id\":1416959221,\"type\":\"prereq\"}],\"name\":\"EE 282\",\"metrics\":{\"centrality\":3,\"complexity ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"curriculum"=>Dict{String,Any}("name"=>"University of Kentucky EE Program","dp_name"=>"University of Kentucky EE Program 4-year Plan","curriculum_terms"=>Dict{String,Any}[Dict("name"=>"Term 1","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"EGR 101","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"Engineering Exploration I","id"=>2071595408,"credits"=>1,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"EGR 102","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>6.0,"blocking factor"=>3,"delay factor"=>3.0),"nameSub"=>"Fundamentals of Engineering Computing","id"=>502542156,"credits"=>2,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>3389674827,"target_id"=>2865398329,"type"=>"coreq")],"name"=>"PHY 231","metrics"=>Dict{String,Any}("centrality"=>62,"complexity"=>16.0,"blocking factor"=>10,"delay factor"=>6.0),"nameSub"=>"General University Physics","id"=>2865398329,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>2865398329,"target_id"=>746915474,"type"=>"coreq")],"name"=>"PHY 241","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>0,"delay factor"=>3.0),"nameSub"=>"General University Physics Lab","id"=>746915474,"credits"=>1,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"CIS/WRD 110","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"nameSub"=>"Composition and Communication I","id"=>858428248,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"MA 113","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>23.0,"blocking factor"=>15,"delay factor"=>8.0),"nameSub"=>"Calculus I","id"=>3389674827,"credits"=>4,"nameCanonical"=>"")],"id"=>1), Dict("name"=>"Term 2","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>502542156,"target_id"=>1123828828,"type"=>"prereq"), Dict("source_id"=>3389674827,"target_id"=>1123828828,"type"=>"coreq"), Dict("source_id"=>2865398329,"target_id"=>1123828828,"type"=>"coreq"), Dict("source_id"=>738464693,"target_id"=>1123828828,"type"=>"coreq")],"name"=>"EGR 103","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>0,"delay factor"=>3.0),"nameSub"=>"Engineering Exploration II","id"=>1123828828,"credits"=>2,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>858428248,"target_id"=>3660518225,"type"=>"prereq")],"name"=>"CIS/WRD 111","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>2.0,"blocking factor"=>0,"delay factor"=>2.0),"nameSub"=>"Composition and Communication II","id"=>3660518225,"credits"=>3,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>3389674827,"target_id"=>2966989896,"type"=>"prereq")],"name"=>"MA 114","metrics"=>Dict{String,Any}("centrality"=>102,"complexity"=>19.0,"blocking factor"=>11,"delay factor"=>8.0),"nameSub"=>"Calculus II","id"=>2966989896,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>"CHE 105","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"nameSub"=>"General College Chemistry I","id"=>738464693,"credits"=>4,"nameCanonical"=>""), Dict("curriculum_requisites"=>Dict{String,Any}[],"name"=>" ","metrics"=>Dict{String,Any}("centrality"=>0,"complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"nameSub"=>"UK Core - Social Sciences","id"=>1586162741,"credits"=>3,"nameCanonical"=>"")],"id"=>2), Dict("name"=>"Term 3","curriculum_items"=>Dict{String,Any}[Dict("curriculum_requisites"=>Dict{String,Any}[Dict("source_id"=>502542156,"target_id"=>1416959221,"type ...
