# %% [markdown]
# # Adapting EE curricula to Incomimg Student Preparation
#
# This notebook analyzes, at a fundamental level, the curricular reforms implemented by the College of Engineering at Wright St. University.  This analysis is specific to the Electrical Engineering (EE) program, and is broadly applicable to EE undergraduate programs at any institution.
#
# To learn more about the reforms implemented at Wright St. University, see:
#
# First, let's take care of the things that allow you to use the CurricularAnalytics.jl toolbox.

# %%
# Activate the CurricularAnalytics.jl package.  You won't need to do this in the future ... 
if split(pwd(),Base.Filesystem.path_separator)[end] != "CurricularAnalytics.jl"
    cd("../../..")
end
println("Current directory: " * split(pwd(),Base.Filesystem.path_separator)[end])
using Pkg
pkg"activate ."
# ... you'll just need to do this
using CurricularAnalytics
# Out:
# Current directory: CurricularAnalytics.jl

# %% [markdown]
# Let's first consider a few electrical engineering curricula.

# %%
include("./examples/Notebooks/WrightSt-Reform/UH_EE_curric.jl")
visualize(dp; notebook=true)
# Out:
# WebIO.Scope("scope-84808637-0943-463e-94fc-c793d21a49e9", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"name\":\"University of Houston EE Program 4-year Plan\",\"curriculum\":{\"name\":\"University of Houston EE Program\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\"HIST 1377\",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"The US to 1877\",\"id\":5753434015150873917,\"num\":\"1377\",\"credits\":3,\"institution\":\"\",\"prefix\":\"HIST\"},{\"curriculum_requisites\":[],\"name\":\"ENGL 1303\",\"metrics\":{\"complexity\":13.0,\"blocking factor\":6,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"First Year Writing I\",\"id\":1691262960464024597,\"num\":\"1303\",\"credits\":3,\"institution\":\"\",\"prefix\":\"ENGL\"},{\"curriculum_requisites\":[{\"source_id\":8457378728145052853,\"target_id\":7614582574842798563,\"type\":\"coreq\"}],\"name\":\"ENGI 1100\",\"metrics\":{\"complexity\":24.0,\"blocking factor\":15,\"delay factor\":9.0},\"canonical_name\":\"\",\"nameSub\":\"Intro to Engr.\",\"id\":7614582574842798563,\"num\":\"1100\",\"credits\":1,\"institution\":\"\",\"prefix\":\"ENGI\"},{\"curriculum_requisites\":[],\"name\":\"MATH 1431\",\"metrics\":{\"complexity\":35.0,\"blocking factor\":23,\"delay factor\":12.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus I\",\"id\":8457378728145052853,\"num\":\"1431\",\"credits\":4,\"institution\":\"\",\"prefix\":\"MATH\"},{\"curriculum_requisites\":[],\"name\":\"CHEM 1331\",\"metrics\":{\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Fund. of Chemistry\",\"id\":1731599015488150122,\"num\":\"1331\",\"credits\":3,\"institution\":\"\",\"prefix\":\"CHEM\"},{\"curriculum_requisites\":[{\"source_id\":1731599015488150122,\"target_id\":7124386063341742882,\"type\":\"coreq\"}],\"name\":\"CHEM 1111\",\"metrics\":{\"complexity\":2.0,\"blocking factor\":0,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Fund. of Chemistry Lab\",\"id\":7124386063341742882,\"num\":\"1111\",\"credits\":1,\"institution\":\"\",\"prefix\":\"CHEM\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\"HIST 1378\",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"US Since 1877\",\"id\":5198608539487903137,\"num\":\"1378\",\"credits\":3,\"institution\":\"\",\"prefix\":\"HIST\"},{\"curriculum_requisites\":[{\"source_id\":1691262960464024597,\"target_id\":670587841930243380,\"type\":\"prereq\"}],\"name\":\"ENGL 1304\",\"metrics\":{\"complexity\":12.0,\"blocking factor\":5,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"First Year Writing II\",\"id\":670587841930243380,\"num\":\"1304\",\"credits\":3,\"institution\":\"\",\"prefix\":\"ENGL\"},{\"curriculum_requisites\":[{\"source_id\":7614582574842798563,\"target_id\":4577290446490159887,\"type\":\"prereq\"},{\"source_id\":8457378728145052853,\"target_id\":4577290446490159887,\"type\":\"prereq\"}],\"name\":\"ENGI 1331\",\"metrics\":{\"complexity\":23.0,\"blocking factor\":14,\"delay factor\":9.0},\"canonical_name\":\"\",\"nameSub\":\"Computing & Prob. Solving\",\"id\":4577290446490159887,\"num\":\"1331\",\"credits\":3,\"institution\":\"\",\"prefix\":\"ENGI\"},{\"curriculum_requisites\":[{\"source_id\":8457378728145052853,\"target_id\":5640407386366066424,\"type\":\"prereq\"}],\"name\":\"MATH 1432\",\"metrics\":{\"complexity\":32.0,\"blocking factor\":20,\"delay factor\":12.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus II\",\"id\":5640407386366066424,\"num\":\"1432\",\"credits\":4,\"institution\":\"\",\"prefix\":\"MATH\"},{\"curriculum_requisites\":[{\"source_id\":5 ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"name"=>"University of Houston EE Program 4-year Plan","curriculum"=>Dict{String,Any}("name"=>"University of Houston EE Program","curriculum_terms"=>Any[Dict{String,Any}("name"=>"Term 1","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"HIST 1377","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"The US to 1877","id"=>5753434015150873917,"num"=>"1377","credits"=>3,"institution"=>"","prefix"=>"HIST"…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"ENGL 1303","metrics"=>Dict{String,Any}("complexity"=>13.0,"blocking factor"=>6,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"First Year Writing I","id"=>1691262960464024597,"num"=>"1303","credits"=>3,"institution"=>"","prefix"=>"ENGL"…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>8457378728145052853,"target_id"=>7614582574842798563,"type"=>"coreq")],"name"=>"ENGI 1100","metrics"=>Dict{String,Any}("complexity"=>24.0,"blocking factor"=>15,"delay factor"=>9.0),"canonical_name"=>"","nameSub"=>"Intro to Engr.","id"=>7614582574842798563,"num"=>"1100","credits"=>1,"institution"=>"","prefix"=>"ENGI"…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"MATH 1431","metrics"=>Dict{String,Any}("complexity"=>35.0,"blocking factor"=>23,"delay factor"=>12.0),"canonical_name"=>"","nameSub"=>"Calculus I","id"=>8457378728145052853,"num"=>"1431","credits"=>4,"institution"=>"","prefix"=>"MATH"…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"CHEM 1331","metrics"=>Dict{String,Any}("complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Fund. of Chemistry","id"=>1731599015488150122,"num"=>"1331","credits"=>3,"institution"=>"","prefix"=>"CHEM"…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1731599015488150122,"target_id"=>7124386063341742882,"type"=>"coreq")],"name"=>"CHEM 1111","metrics"=>Dict{String,Any}("complexity"=>2.0,"blocking factor"=>0,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Fund. of Chemistry Lab","id"=>7124386063341742882,"num"=>"1111","credits"=>1,"institution"=>"","prefix"=>"CHEM"…)],"id"=>1), Dict{String,Any}("name"=>"Term 2","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"HIST 1378","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"US Since 1877","id"=>5198608539487903137,"num"=>"1378","credits"=>3,"institution"=>"","prefix"=>"HIST"…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1691262960464024597,"target_id"=>670587841930243380,"type"=>"prereq")],"name"=>"ENGL 1304","metrics"=>Dict{String,Any}("complexity"=>12.0,"blocking factor"=>5,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"First Year Writing II","id"=>670587841930243380,"num"=>"1304","credits"=>3,"institution"=>"","prefix"=>"ENGL"…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>7614582574842798563,"target_id"=>4577290446490159887,"type"=>"prereq"), Dict{String,Any}("source_id"=>8457378728145052853,"target_id"=>4577290446490159887,"type"=>"prereq")],"name"=>"ENGI 1331","metrics"=>Dict{String,Any}("complexity"=>23.0,"blocking factor"=>14,"delay factor"=>9.0),"canonical_name"=>"","nameSub"=>"Computing & Prob. Solving","id"=>4577290446490159887,"num"=>"1331","credits"=>3,"institution"=>"","prefix"=>"ENGI"…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>8457378728145052853,"target_id"=>5640407386366066424,"type"=>"prereq")],"name"=>"MATH 1432","metrics"=>Dict{String,Any}("complexity"=>32.0,"blocking factor"=>20,"delay factor"=>12.0),"canonical_name"=>"","nameSub"=>"Calculus II","id"=>5640407386366066424,"num"=>"1432","credits"=>4,"institution"=>"","prefix"=>"MATH"…), Dict{String,Any}("curriculum_requisites"=>An ...

# %%
include("./examples/Notebooks/WrightSt-Reform/Cornell_EE_curric.jl")
visualize(dp; notebook=true)
# Out:
# WebIO.Scope("scope-465cfa82-57f5-4522-ace8-0ecac3044b0b", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"name\":\"Cornell University EE Program 4-year Plan\",\"curriculum\":{\"name\":\"Cornell University EE Program\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\"CHEM  2090\",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"Engineering Gen. Chemistry\",\"id\":8677861332106437271,\"num\":\"2090\",\"credits\":3,\"institution\":\"\",\"prefix\":\"CHEM \"},{\"curriculum_requisites\":[],\"name\":\"MATH 1910\",\"metrics\":{\"complexity\":15.0,\"blocking factor\":10,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus for Engineers\",\"id\":281047312371005014,\"num\":\"1910\",\"credits\":3,\"institution\":\"\",\"prefix\":\"MATH\"},{\"curriculum_requisites\":[],\"name\":\"ENGRI 1xxx\",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"Engineering Distribution\",\"id\":7816898264354205032,\"num\":\"1xxx\",\"credits\":3,\"institution\":\"\",\"prefix\":\"ENGRI\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"1st Yr Writing Seminar\",\"id\":8028046533651354146,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"PE\",\"id\":2718286302356715064,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":281047312371005014,\"target_id\":3635132327825632527,\"type\":\"prereq\"}],\"name\":\"PHYS 1112\",\"metrics\":{\"complexity\":9.0,\"blocking factor\":4,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Physics I: Mechanics & Heat\",\"id\":3635132327825632527,\"num\":\"1112\",\"credits\":3,\"institution\":\"\",\"prefix\":\"PHYS\"},{\"curriculum_requisites\":[{\"source_id\":281047312371005014,\"target_id\":8684743187199173961,\"type\":\"prereq\"}],\"name\":\"MATH 1920\",\"metrics\":{\"complexity\":12.0,\"blocking factor\":8,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Multivariable Calc. for Engineers\",\"id\":8684743187199173961,\"num\":\"1920\",\"credits\":3,\"institution\":\"\",\"prefix\":\"MATH\"},{\"curriculum_requisites\":[],\"name\":\"CS 111x\",\"metrics\":{\"complexity\":6.0,\"blocking factor\":3,\"delay factor\":3.0},\"canonical_name\":\"\",\"nameSub\":\"Intro. to Computing\",\"id\":2078287318733809424,\"num\":\"111x\",\"credits\":3,\"institution\":\"\",\"prefix\":\"CS\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"1st Yr Writing Seminar\",\"id\":8363110905229104199,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":1.0,\"blocking factor\":0,\"delay factor\":1.0},\"canonical_name\":\"\",\"nameSub\":\"PE\",\"id\":5657369272730891473,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":3635132327825632527,\"target_id\":8452515014410430659,\"type\":\"prereq\"},{\"source_id\":8684743187199173961,\"target_id\":8452515014410430659,\"type\":\"prereq\"}],\"name\":\"PHYS 2213\",\"metrics\":{\"complexity\":8.0,\"blocking factor\":3,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Physics II: Electromagnetism\",\"id\":8452515014 ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"name"=>"Cornell University EE Program 4-year Plan","curriculum"=>Dict{String,Any}("name"=>"Cornell University EE Program","curriculum_terms"=>Any[Dict{String,Any}("name"=>"Term 1","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"CHEM  2090","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"Engineering Gen. Chemistry","id"=>8677861332106437271,"num"=>"2090","credits"=>3,"institution"=>"","prefix"=>"CHEM "…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"MATH 1910","metrics"=>Dict{String,Any}("complexity"=>15.0,"blocking factor"=>10,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Calculus for Engineers","id"=>281047312371005014,"num"=>"1910","credits"=>3,"institution"=>"","prefix"=>"MATH"…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"ENGRI 1xxx","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"Engineering Distribution","id"=>7816898264354205032,"num"=>"1xxx","credits"=>3,"institution"=>"","prefix"=>"ENGRI"…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"1st Yr Writing Seminar","id"=>8028046533651354146,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"PE","id"=>2718286302356715064,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>1), Dict{String,Any}("name"=>"Term 2","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>281047312371005014,"target_id"=>3635132327825632527,"type"=>"prereq")],"name"=>"PHYS 1112","metrics"=>Dict{String,Any}("complexity"=>9.0,"blocking factor"=>4,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Physics I: Mechanics & Heat","id"=>3635132327825632527,"num"=>"1112","credits"=>3,"institution"=>"","prefix"=>"PHYS"…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>281047312371005014,"target_id"=>8684743187199173961,"type"=>"prereq")],"name"=>"MATH 1920","metrics"=>Dict{String,Any}("complexity"=>12.0,"blocking factor"=>8,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Multivariable Calc. for Engineers","id"=>8684743187199173961,"num"=>"1920","credits"=>3,"institution"=>"","prefix"=>"MATH"…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>"CS 111x","metrics"=>Dict{String,Any}("complexity"=>6.0,"blocking factor"=>3,"delay factor"=>3.0),"canonical_name"=>"","nameSub"=>"Intro. to Computing","id"=>2078287318733809424,"num"=>"111x","credits"=>3,"institution"=>"","prefix"=>"CS"…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"1st Yr Writing Seminar","id"=>8363110905229104199,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>1.0,"blocking factor"=>0,"delay factor"=>1.0),"canonical_name"=>"","nameSub"=>"PE","id"=>5657369272730891473,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>2), Dict{String,Any}("name"=>"Term 3","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3635132327825632527,"target_id"=>8452515014410430659,"type"=>"prereq"), Dict{String,Any}("source_id"=>8684743187199173961,"target_id"=>8452515014410430659,"type"=>"prereq")],"name"=>"PHYS 2213","metrics"=>Dict{String,Any}("complexity"=>8.0,"blocking factor"=>3,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Physics II: Electromagnetism","id" ...

# %% [markdown]
# ## Storing a Curriculum
# You can store your curriculum and degree plans as a CSV file, and then using the CurricularAnalytics.jl toolbox to analyze them. Below is an example of what the CSV file looks like. In this case, we're analyzing a portion of a curriculum that we refer to as a **curriculur design pattern**.
# ![CSV-example.png](attachment:CSV-example.png)

# %% [markdown]
# ## Reading a Curriculum from a File and Creating a Curriculum Object
# The following command can be used to read a curriculum, analyze its complexity and then visualize it.
# First, read in the CSV file and create the degree plan object:

# %%
csv_to_json("./examples/Notebooks/WrightSt-Reform/EE-CalculusReady.csv", "recent-visualization.json")
dp1 = read_degree_plan("recent-visualization.json")
println("Done")
# Out:
# Done

# %% [markdown]
# ## Analyzing the Complexity of a Curriculum
# The following command will analyze the complexity of the curriculum associated with the degree plan object that we just created.  To learn more about **curricular complexity**, see:

# %%
complexity(dp1.curriculum)
# Out:
# (35.0, Number[10.0, 7.0, 3.0, 3.0, 3.0, 5.0, 4.0])

# %% [markdown]
# ## Visualizing a Degree Plan
# Let's now visualize the curricular design pattern that was stored in the degree plan object.  To do this, using the following command.  Note that because we'd like to display the design pattern within the Jupyter notebook, you need to pass in the flag `notebook=true`.  By hovering over courses in the visualization, you can see the various complexity metrics that have been computed.

# %%
visualize(dp1; notebook=true)
# Out:
# WebIO.Scope("scope-5062dfc7-e849-457c-8a3a-1e99363ac2a2", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"name\":\"\",\"curriculum\":{\"name\":\"\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":10.0,\"blocking factor\":6,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus I\",\"id\":1,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":2,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":7.0,\"blocking factor\":3,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus II\",\"id\":2,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":3,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Physics I\",\"id\":3,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":4,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":3.0,\"blocking factor\":1,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Programming I\",\"id\":4,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":5,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":3.0,\"blocking factor\":0,\"delay factor\":3.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus III\",\"id\":5,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":6,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":5.0,\"blocking factor\":1,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Differential Eqs.\",\"id\":6,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":3},{\"name\":\"Term 4\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":4,\"target_id\":7,\"type\":\"strict-coreq\"},{\"source_id\":3,\"target_id\":7,\"type\":\"strict-coreq\"},{\"source_id\":6,\"target_id\":7,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":4.0,\"blocking factor\":0,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Circuits I\",\"id\":7,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":4}],\"CIP\":\"\",\"id\":62119800256760722,\"institution\":\"\"}},\"*\"); window.removeEventListener(\"message\",window.messageReceived); window.messageReceived=(function (event){return (event.data.curriculum!==undefined) ? (_webIOScope.setObservableValue({\"name\":\"curriculum-data\",\"scope\":\"scope-5062dfc7-e849-457c-8a3a-1e99363ac2a2\",\"id\":\"ob_17\",\"type\":\"observable\"},event.data.curriculum)) : undefined}); window.addEventListener(\"message\",window.messageReceived); window.removeEventListener(\"message\",window.messageReceived); window.messageReceived=(function (event){return (event.data.curriculum!==undefined) ? (console.log(event.data.curriculum)) : undefined}); return window.addEventListener(\"message\",window.messageReceived)})")),:style=>Dict(:padding=>"0",:height=>"100vh",:margin=>"0",:border=>"none",:width=>"100%")), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("curriculum-data"=>(Observable{Dict{String,Any}} with 1 listeners. Value:
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"name"=>"","curriculum"=>Dict{String,Any}("name"=>"","curriculum_terms"=>Any[Dict{String,Any}("name"=>"Term 1","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>10.0,"blocking factor"=>6,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Calculus I","id"=>1,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…)],"id"=>1), Dict{String,Any}("name"=>"Term 2","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>2,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>7.0,"blocking factor"=>3,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Calculus II","id"=>2,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>3,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Physics I","id"=>3,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>4,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>3.0,"blocking factor"=>1,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Programming I","id"=>4,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>2), Dict{String,Any}("name"=>"Term 3","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>5,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>3.0,"blocking factor"=>0,"delay factor"=>3.0),"canonical_name"=>"","nameSub"=>"Calculus III","id"=>5,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>6,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>5.0,"blocking factor"=>1,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Differential Eqs.","id"=>6,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>3), Dict{String,Any}("name"=>"Term 4","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>4,"target_id"=>7,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>3,"target_id"=>7,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>6,"target_id"=>7,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>4.0,"blocking factor"=>0,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Circuits I","id"=>7,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>4)],"CIP"=>"","id"=>62119800256760722,"institution"=>"")), nothing)), Set(String[]), nothing, Any[], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(WebIO.AbstractConnection[]), Channel{WebIO.AbstractConnection}(sz_max:32,sz_curr:0)))

# %% [markdown]
# ### Analyzing the Curricular Design Pattern
#
# #### The pattern for Calculus I ready students.
# In the design pattern displayed above, for an electrical engineering program, notice that the assumption is that students enter Calculus I ready, and that if they are able to successfully complete all of the prerequisite courses, they will be able to take Circuits I (a foundational electrical engineering course) in the second semester of their sophomore year. Notice that the overall curricular complexity of this design pattern is ?.
#
# #### The pattern for Precalculus ready students.
# Now let's look at what happens to students who are not Calculus I ready when they enter the institution -- let's assume instead that they are Precalculus ready.  The curricular complexity increases to ?.

# %%
csv_to_json("./examples/Notebooks/WrightSt-Reform/EE-PrecalculusReady.csv", "recent-visualization.json")
dp = read_degree_plan("recent-visualization.json")
complexity(dp.curriculum)
visualize(dp; notebook=true)
# Out:
# WebIO.Scope("scope-7b9c8bf7-af8a-422c-836c-22ad70145e7c", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"name\":\"\",\"curriculum\":{\"name\":\"\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":12.0,\"blocking factor\":7,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Precalculus\",\"id\":1,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":2,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":11.0,\"blocking factor\":6,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus I\",\"id\":2,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":3,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":8.0,\"blocking factor\":3,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus II\",\"id\":3,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":4,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":4.0,\"blocking factor\":1,\"delay factor\":3.0},\"canonical_name\":\"\",\"nameSub\":\"Physics I\",\"id\":4,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":5,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":4.0,\"blocking factor\":1,\"delay factor\":3.0},\"canonical_name\":\"\",\"nameSub\":\"Programming I\",\"id\":5,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":3},{\"name\":\"Term 4\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":3,\"target_id\":6,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":4.0,\"blocking factor\":0,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus III\",\"id\":6,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3,\"target_id\":7,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":6.0,\"blocking factor\":1,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Differential Eqs.\",\"id\":7,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":4},{\"name\":\"Term 5\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":7,\"target_id\":8,\"type\":\"strict-coreq\"},{\"source_id\":4,\"target_id\":8,\"type\":\"strict-coreq\"},{\"source_id\":5,\"target_id\":8,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":5.0,\"blocking factor\":0,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Circuits I\",\"id\":8,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":5}],\"CIP\":\"\",\"id\":62119800256760722,\"institution\":\"\"}},\"*\"); window.removeEventListener(\"message\",window.messageReceived); window.messageReceived=(function (event){return (event.data.curriculum!==undefined) ? (_webIOScope.setObservableValue({\"name\":\"curriculum-data\",\"scope\":\"scope-7b9c8bf7-af8a-422c-836c-22ad70145e7c\",\"id\":\"ob_07\",\"type\":\"observable\"},event.data.curriculum)) : undefined}); window.addEventListener(\"message\",window.messageReceived); window.removeEventListener(\"message\",window.messageReceived); window.messageReceived=(function (event){return (event.data.curriculum!==undefined) ? (console.log(event.data.curriculum)) : undefined}); return window.addEventListener(\"message\",window.messageReceived)})")),:style=>Dict(:padding=>"0",:height=>"100vh",:margin=>"0",:border=>"none",:width=>"100%" ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"name"=>"","curriculum"=>Dict{String,Any}("name"=>"","curriculum_terms"=>Any[Dict{String,Any}("name"=>"Term 1","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>12.0,"blocking factor"=>7,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Precalculus","id"=>1,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>1), Dict{String,Any}("name"=>"Term 2","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>2,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>11.0,"blocking factor"=>6,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Calculus I","id"=>2,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…)],"id"=>2), Dict{String,Any}("name"=>"Term 3","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>3,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>8.0,"blocking factor"=>3,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Calculus II","id"=>3,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>4,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>4.0,"blocking factor"=>1,"delay factor"=>3.0),"canonical_name"=>"","nameSub"=>"Physics I","id"=>4,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>5,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>4.0,"blocking factor"=>1,"delay factor"=>3.0),"canonical_name"=>"","nameSub"=>"Programming I","id"=>5,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>3), Dict{String,Any}("name"=>"Term 4","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3,"target_id"=>6,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>4.0,"blocking factor"=>0,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Calculus III","id"=>6,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3,"target_id"=>7,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>6.0,"blocking factor"=>1,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Differential Eqs.","id"=>7,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>4), Dict{String,Any}("name"=>"Term 5","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>7,"target_id"=>8,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>4,"target_id"=>8,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>5,"target_id"=>8,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>5.0,"blocking factor"=>0,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Circuits I","id"=>8,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>5)],"CIP"=>"","id"=>62119800256760722,"institution"=>"")), nothing)), Set(String[]), nothing, Any[], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(WebIO.AbstractConnection[]), Channel{WebIO.AbstractConnection}(sz_max:32,sz_curr:0)))

# %% [markdown]
# #### The pattern for College Algebra ready students.
# Now let's look at what happens to students who are not Precalculus ready when they enter the institution -- let's assume instead that they are College Algebra ready. Notice that the longest path through the design pattern is growing, and that due to the prerequisite structure there is limited opportunity to move courses around.  The curricular complexity is now ?.

# %%
csv_to_json("./examples/Notebooks/WrightSt-Reform/EE-AlgebraReady.csv", "recent-visualization.json")
dp = read_degree_plan("recent-visualization.json")
complexity(dp.curriculum)
visualize(dp; notebook=true)
# Out:
# WebIO.Scope("scope-d9bcd9f8-9fa4-445b-b521-806c63b99273", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"name\":\"\",\"curriculum\":{\"name\":\"\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":14.0,\"blocking factor\":8,\"delay factor\":6.0},\"canonical_name\":\"\",\"nameSub\":\"College Algebra\",\"id\":1,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":2,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":13.0,\"blocking factor\":7,\"delay factor\":6.0},\"canonical_name\":\"\",\"nameSub\":\"Precalculus\",\"id\":2,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":3,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":12.0,\"blocking factor\":6,\"delay factor\":6.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus I\",\"id\":3,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"}],\"id\":3},{\"name\":\"Term 4\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":3,\"target_id\":4,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":9.0,\"blocking factor\":3,\"delay factor\":6.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus II\",\"id\":4,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3,\"target_id\":5,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":5.0,\"blocking factor\":1,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Physics I\",\"id\":5,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3,\"target_id\":6,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":5.0,\"blocking factor\":1,\"delay factor\":4.0},\"canonical_name\":\"\",\"nameSub\":\"Programming I\",\"id\":6,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":4},{\"name\":\"Term 5\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":4,\"target_id\":7,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":5.0,\"blocking factor\":0,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus III\",\"id\":7,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":4,\"target_id\":8,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":7.0,\"blocking factor\":1,\"delay factor\":6.0},\"canonical_name\":\"\",\"nameSub\":\"Differential Eqs.\",\"id\":8,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":5},{\"name\":\"Term 6\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":5,\"target_id\":9,\"type\":\"strict-coreq\"},{\"source_id\":8,\"target_id\":9,\"type\":\"strict-coreq\"},{\"source_id\":6,\"target_id\":9,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":6.0,\"blocking factor\":0,\"delay factor\":6.0},\"canonical_name\":\"\",\"nameSub\":\"Circuits I\",\"id\":9,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":6}],\"CIP\":\"\",\"id\":62119800256760722,\"institution\":\"\"}},\"*\"); window.removeEventListener(\"message\",window.messageReceived); window.messageReceived=(function (event){return (event.data.curriculum!==undefined) ? (_webIOScope.setObservableValue({\"name\":\"curriculum-data\",\"scope\":\"scope-d9bcd9f8-9fa4-445b-b521-806c63b99273\",\"id\":\"ob_08\",\"type\":\"observable\"},event.data.curriculum)) : undefined}); window.addEventListener(\"message\",window.messageReceive ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"name"=>"","curriculum"=>Dict{String,Any}("name"=>"","curriculum_terms"=>Any[Dict{String,Any}("name"=>"Term 1","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>14.0,"blocking factor"=>8,"delay factor"=>6.0),"canonical_name"=>"","nameSub"=>"College Algebra","id"=>1,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>1), Dict{String,Any}("name"=>"Term 2","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>2,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>13.0,"blocking factor"=>7,"delay factor"=>6.0),"canonical_name"=>"","nameSub"=>"Precalculus","id"=>2,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>2), Dict{String,Any}("name"=>"Term 3","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>3,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>12.0,"blocking factor"=>6,"delay factor"=>6.0),"canonical_name"=>"","nameSub"=>"Calculus I","id"=>3,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…)],"id"=>3), Dict{String,Any}("name"=>"Term 4","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3,"target_id"=>4,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>9.0,"blocking factor"=>3,"delay factor"=>6.0),"canonical_name"=>"","nameSub"=>"Calculus II","id"=>4,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3,"target_id"=>5,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>5.0,"blocking factor"=>1,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Physics I","id"=>5,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3,"target_id"=>6,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>5.0,"blocking factor"=>1,"delay factor"=>4.0),"canonical_name"=>"","nameSub"=>"Programming I","id"=>6,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>4), Dict{String,Any}("name"=>"Term 5","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>4,"target_id"=>7,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>5.0,"blocking factor"=>0,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Calculus III","id"=>7,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>4,"target_id"=>8,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>7.0,"blocking factor"=>1,"delay factor"=>6.0),"canonical_name"=>"","nameSub"=>"Differential Eqs.","id"=>8,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>5), Dict{String,Any}("name"=>"Term 6","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>5,"target_id"=>9,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>8,"target_id"=>9,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>6,"target_id"=>9,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>6.0,"blocking factor"=>0,"delay factor"=>6.0),"canonical_name"=>"","nameSub"=>"Circuits I","id"=>9,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>6)],"CIP"=>"","id"=>62119800256760722,"institution"=>"")), nothing)), Set(String[]), nothing, Any[], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(WebIO.AbstractConnection[]), Channel{WebIO.AbstractConnection}(sz_max:32,sz_curr:0)))

# %% [markdown]
# #### The pattern for Foundational Math students
# Finally let's look at what happens to students who enter the institution starting with Foundational Math.  The curricular complexity is now ?.

# %%
csv_to_json("./examples/Notebooks/WrightSt-Reform/EE-FoundationalMath.csv", "recent-visualization.json")
dp = read_degree_plan("recent-visualization.json")
complexity(dp.curriculum)
visualize(dp; notebook=true)
# Out:
# WebIO.Scope("scope-51237b34-925e-4585-9bf5-91d805ae3024", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"name\":\"\",\"curriculum\":{\"name\":\"\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":16.0,\"blocking factor\":9,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"Foundational Math\",\"id\":1,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":2,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":15.0,\"blocking factor\":8,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"College Algebra\",\"id\":2,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":3,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":14.0,\"blocking factor\":7,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"Precalculus\",\"id\":3,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":3},{\"name\":\"Term 4\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":3,\"target_id\":4,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":13.0,\"blocking factor\":6,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus I\",\"id\":4,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"}],\"id\":4},{\"name\":\"Term 5\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":4,\"target_id\":5,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":10.0,\"blocking factor\":3,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus II\",\"id\":5,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":4,\"target_id\":6,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":6.0,\"blocking factor\":1,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Physics I\",\"id\":6,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":4,\"target_id\":7,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":6.0,\"blocking factor\":1,\"delay factor\":5.0},\"canonical_name\":\"\",\"nameSub\":\"Programming I\",\"id\":7,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":5},{\"name\":\"Term 6\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":5,\"target_id\":8,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":6.0,\"blocking factor\":0,\"delay factor\":6.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus III\",\"id\":8,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":5,\"target_id\":9,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":8.0,\"blocking factor\":1,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"Differential Eqs.\",\"id\":9,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":6},{\"name\":\"Term 7\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":7,\"target_id\":10,\"type\":\"strict-coreq\"},{\"source_id\":9,\"target_id\":10,\"type\":\"strict-coreq\"},{\"source_id\":6,\"target_id\":10,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":7.0,\"blocking factor\":0,\"delay factor\":7.0},\"canonical_name\":\"\",\"nameSub\":\"Circuits I\",\"id\":10,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":7}],\"CIP\":\"\",\"id\":62119800256760722,\"institution\":\"\"}},\"*\"); window.removeEventListener(\"messag ...
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"name"=>"","curriculum"=>Dict{String,Any}("name"=>"","curriculum_terms"=>Any[Dict{String,Any}("name"=>"Term 1","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>16.0,"blocking factor"=>9,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"Foundational Math","id"=>1,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>1), Dict{String,Any}("name"=>"Term 2","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>2,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>15.0,"blocking factor"=>8,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"College Algebra","id"=>2,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>2), Dict{String,Any}("name"=>"Term 3","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>3,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>14.0,"blocking factor"=>7,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"Precalculus","id"=>3,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>3), Dict{String,Any}("name"=>"Term 4","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3,"target_id"=>4,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>13.0,"blocking factor"=>6,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"Calculus I","id"=>4,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…)],"id"=>4), Dict{String,Any}("name"=>"Term 5","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>4,"target_id"=>5,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>10.0,"blocking factor"=>3,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"Calculus II","id"=>5,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>4,"target_id"=>6,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>6.0,"blocking factor"=>1,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Physics I","id"=>6,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>4,"target_id"=>7,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>6.0,"blocking factor"=>1,"delay factor"=>5.0),"canonical_name"=>"","nameSub"=>"Programming I","id"=>7,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>5), Dict{String,Any}("name"=>"Term 6","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>5,"target_id"=>8,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>6.0,"blocking factor"=>0,"delay factor"=>6.0),"canonical_name"=>"","nameSub"=>"Calculus III","id"=>8,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>5,"target_id"=>9,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>8.0,"blocking factor"=>1,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"Differential Eqs.","id"=>9,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>6), Dict{String,Any}("name"=>"Term 7","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>7,"target_id"=>10,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>9,"target_id"=>10,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>6,"target_id"=>10,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>7.0,"blocking factor"=>0,"delay factor"=>7.0),"canonical_name"=>"","nameSub"=>"Circuits I","id"=>10,"num"=>"","credits"=>3,"institution"=>"","prefi ...

# %% [markdown]
# ### Wright State University Reform
# A reformed curriculum was implemented at Wright State University.  The key factor enabling this innovation is that fact that a typical Circuits I course only requires the ability to solve first order differential equations, and that it's possible to teach basic concepts regarding first order differential equations, as well as solution techniques, to students prior to taking Calculus I.  At Wright State University, this knowledge is imparted in the Engineering 101 class in the very first semester.  Here's what the reformed curriculum looks like:

# %%
csv_to_json("./examples/Notebooks/WrightSt-Reform/EE-Reformed.csv", "recent-visualization.json")
dp = read_degree_plan("recent-visualization.json")
complexity(dp.curriculum)
visualize(dp; notebook=true)
# Out:
# WebIO.Scope("scope-785a4a87-2d52-4b3d-b573-1fade039d246", WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :iframe), Any[""], Dict{Symbol,Any}(:src=>"http://localhost:8156",:id=>"curriculum",:events=>Dict(:load=>JSString("(function (){this.contentWindow.postMessage({\"options\":{\"hideTerms\":false,\"edit\":false},\"name\":\"\",\"curriculum\":{\"name\":\"\",\"curriculum_terms\":[{\"name\":\"Term 1\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":7.0,\"blocking factor\":4,\"delay factor\":3.0},\"canonical_name\":\"\",\"nameSub\":\"Engineering 101\",\"id\":1,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"}],\"id\":1},{\"name\":\"Term 2\",\"curriculum_items\":[{\"curriculum_requisites\":[],\"name\":\" \",\"metrics\":{\"complexity\":4.0,\"blocking factor\":2,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus I\",\"id\":2,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":4,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":2.0,\"blocking factor\":0,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Physics I\",\"id\":4,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":5,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":2.0,\"blocking factor\":0,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Programming I\",\"id\":5,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":2},{\"name\":\"Term 3\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":1,\"target_id\":3,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":4.0,\"blocking factor\":1,\"delay factor\":3.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus II\",\"id\":3,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"}],\"id\":3},{\"name\":\"Term 4\",\"curriculum_items\":[{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":6,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":2.0,\"blocking factor\":0,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Calculus III\",\"id\":6,\"num\":\"\",\"credits\":4,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":2,\"target_id\":7,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":2.0,\"blocking factor\":0,\"delay factor\":2.0},\"canonical_name\":\"\",\"nameSub\":\"Differential Eqs.\",\"id\":7,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"},{\"curriculum_requisites\":[{\"source_id\":3,\"target_id\":8,\"type\":\"strict-coreq\"},{\"source_id\":1,\"target_id\":8,\"type\":\"strict-coreq\"}],\"name\":\" \",\"metrics\":{\"complexity\":3.0,\"blocking factor\":0,\"delay factor\":3.0},\"canonical_name\":\"\",\"nameSub\":\"Circuits I\",\"id\":8,\"num\":\"\",\"credits\":3,\"institution\":\"\",\"prefix\":\"\"}],\"id\":4}],\"CIP\":\"\",\"id\":62119800256760722,\"institution\":\"\"}},\"*\"); window.removeEventListener(\"message\",window.messageReceived); window.messageReceived=(function (event){return (event.data.curriculum!==undefined) ? (_webIOScope.setObservableValue({\"name\":\"curriculum-data\",\"scope\":\"scope-785a4a87-2d52-4b3d-b573-1fade039d246\",\"id\":\"ob_18\",\"type\":\"observable\"},event.data.curriculum)) : undefined}); window.addEventListener(\"message\",window.messageReceived); window.removeEventListener(\"message\",window.messageReceived); window.messageReceived=(function (event){return (event.data.curriculum!==undefined) ? (console.log(event.data.curriculum)) : undefined}); return window.addEventListener(\"message\",window.messageReceived)})")),:style=>Dict(:padding=>"0",:height=>"100vh",:margin=>"0",:border=>"none",:width=>"100%")), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("curriculum-data"=>(Observable{Dict{String,Any}} with 1 listeners. Value:
# Dict{String,Any}("options"=>Dict{String,Any}("hideTerms"=>false,"edit"=>false),"name"=>"","curriculum"=>Dict{String,Any}("name"=>"","curriculum_terms"=>Any[Dict{String,Any}("name"=>"Term 1","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>7.0,"blocking factor"=>4,"delay factor"=>3.0),"canonical_name"=>"","nameSub"=>"Engineering 101","id"=>1,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…)],"id"=>1), Dict{String,Any}("name"=>"Term 2","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>4.0,"blocking factor"=>2,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Calculus I","id"=>2,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>4,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>2.0,"blocking factor"=>0,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Physics I","id"=>4,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>5,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>2.0,"blocking factor"=>0,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Programming I","id"=>5,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>2), Dict{String,Any}("name"=>"Term 3","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>1,"target_id"=>3,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>4.0,"blocking factor"=>1,"delay factor"=>3.0),"canonical_name"=>"","nameSub"=>"Calculus II","id"=>3,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…)],"id"=>3), Dict{String,Any}("name"=>"Term 4","curriculum_items"=>Any[Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>6,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>2.0,"blocking factor"=>0,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Calculus III","id"=>6,"num"=>"","credits"=>4,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>2,"target_id"=>7,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>2.0,"blocking factor"=>0,"delay factor"=>2.0),"canonical_name"=>"","nameSub"=>"Differential Eqs.","id"=>7,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…), Dict{String,Any}("curriculum_requisites"=>Any[Dict{String,Any}("source_id"=>3,"target_id"=>8,"type"=>"strict-coreq"), Dict{String,Any}("source_id"=>1,"target_id"=>8,"type"=>"strict-coreq")],"name"=>" ","metrics"=>Dict{String,Any}("complexity"=>3.0,"blocking factor"=>0,"delay factor"=>3.0),"canonical_name"=>"","nameSub"=>"Circuits I","id"=>8,"num"=>"","credits"=>3,"institution"=>"","prefix"=>""…)],"id"=>4)],"CIP"=>"","id"=>62119800256760722,"institution"=>"")), nothing)), Set(String[]), nothing, Any[], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:0), Set(WebIO.AbstractConnection[]), Channel{WebIO.AbstractConnection}(sz_max:32,sz_curr:0)))
# ┌ Info: Closed (19):  💀    4↑     4↓🔒 928s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (18):  💀    3↑     3↓🔒 928s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (17):  💀    3↑     3↓🔒 928s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (16):  💀    5↑     5↓🔒 928s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (8):  💀    2↑     2↓🔒 3207s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (10):  💀    1↑     1↓🔒 3207s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (9):  💀    1↑     1↓🔒 3207s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
# ┌ Info: Closed (11):  💀    1↑     1↓🔒 3207s 127.0.0.1:8156:8156 ≣16
# └ @ HTTP.Servers /Users/heileman/.julia/packages/HTTP/YjRCz/src/Servers.jl:351
