# %%
if split(pwd(),Base.Filesystem.path_separator)[end] != "CurricularAnalytics.jl"
    cd("../..")
end
println("Current directory: " * split(pwd(),Base.Filesystem.path_separator)[end])
using Pkg
pkg"activate ."
using CurricularAnalytics
# Out:
# Current directory: CurricularAnalytics.jl
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/41794c50334d4e214c4ed8746cf62efbfa8785f6-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/41794c50334d4e214c4ed8746cf62efbfa8785f6-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")

# %%
curric = read_csv("examples/UKY_EE_curric.csv")
println("Number of courses in curriculum: "*string(length(curric.courses)))
println("Total credit hours: "*string(total_credits(curric)))
# Out:
# Number of courses in curriculum: 43
# Total credit hours: 131

# %%
include("src/Optimization.jl")
out = find_min_terms_opt(curric; max_terms=12,max_credits_per_term=21)
if out[1]
    println("Optimal solution found for "*string(out[3])*" terms")
end
dp = DegreePlan("", curric, out[2])
visualize(dp, notebook=true)
# Out:
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# Optimize a model with 84 rows, 516 columns and 1728 nonzeros
# Variable types: 0 continuous, 516 integer (516 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 0 rows and 65 columns
# Presolve time: 0.02s
# Presolved: 84 rows, 451 columns, 1353 nonzeros
# Variable types: 0 continuous, 451 integer (451 binary)
# Found heuristic solution: objective 158.0000000
#
# Root relaxation: objective 1.478974e+02, 165 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  147.89744    0   32  158.00000  147.89744  6.39%     -    0s
# H    0     0                     153.0000000  147.89744  3.34%     -    0s
# ...

# %%
#out = balance_terms_opt(curric; max_terms=7,max_credits_per_term=21)
out = balance_terms_opt(curric; max_terms=out[3],max_credits_per_term=21)
if out[1]
    println("Optimal solution found for "*string(out[3])*" terms")
end
dp = DegreePlan("", curric, out[2])
visualize(dp, notebook=true)
# Out:
# ┌ Warning: A variable or constraint named term is already attached to this model. If creating constraints programmatically, use the anonymous constraint syntax con = @constraint(m, ...).
# └ @ JuMP /Users/heileman/.julia/packages/JuMP/PbnIJ/src/JuMP.jl:852
# Academic license - for non-commercial use only
# Optimize a model with 98 rows, 308 columns and 2353 nonzeros
# Variable types: 7 continuous, 301 integer (301 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 0 rows and 60 columns
# Presolve time: 0.01s
# Presolved: 98 rows, 248 columns, 957 nonzeros
# Variable types: 0 continuous, 248 integer (236 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 0.000000e+00, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# ...

# %%
include("src/Optimization.jl")
out = balance_terms_opt(curric; max_terms=7,max_credits_per_term=21)
if out[1]
    println("Optimal solution found for "*string(out[3])*" terms")
end
dp = DegreePlan("", curric, out[2])
visualize(dp, notebook=true)
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 98 rows, 308 columns and 2353 nonzeros
# Variable types: 7 continuous, 301 integer (301 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 0 rows and 60 columns
# Presolve time: 0.01s
# Presolved: 98 rows, 248 columns, 957 nonzeros
# Variable types: 0 continuous, 248 integer (236 binary)
# Found heuristic solution: objective 14.0000000
#
# Root relaxation: objective 0.000000e+00, 69 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   20   14.00000    0.00000   100%     -    0s
# H    0     0                      10.0000000    0.00000   100%     -    0s
# ...
